# %%
import os
import cv2
import csv
import glob
import json
import pprint

import math

import numpy as np
import pandas as pd

import scipy
import matplotlib.pyplot as plt

# %%
data_gt = pd.read_csv("./features.csv", index_col="VIDEO")

# %%
data_gt
# Out:
#           NUMBER_OF_HITS  HIT_INTENSITY  NUMBER_OF_TUG  TOTAL_FRAMES_IN_TUG  \
# VIDEO
# E1_t10                 2              0              2                   23
# E1_t11                 2              0              1                   19
# E1_t12                 2              0              3                   26
# E1_t1                  2              1              1                    9
# E1_t2                  0              0              1                    3
# E1_t3                  0              0              2                   19
# E1_t4                  1              0              1                   17
# E1_t5                  1              0              1                   15
# E1_t6                  2              0              1                   16
# E1_t7                  2              1              1                   31
# E1_t8                  1              0              3                   12
# E1_t9                  1              0              1                   18
# E2_t10                 0              0              0                    0
# E2_t11                 2              0              1                    8
# E2_t12                 1              1              3                   26
# E2_t1                  2              0              1                    5
# E2_t2                  2              0              2                   42
# E2_t3                  2              0              1                   23
# E2_t4                  1              0              3                   18
# E2_t5                  1              0              0                    0
# E2_t6                  1              0              2                   37
# E2_t7                  2              0              4                   76
# E2_t8                  2              0              0                    0
# E2_t9                  2              0              0                    0
# E3_t10                 0              0              0                    0
# E3_t11                 2              0              2                   24
# E3_t12                 2              0              0                    0
# E3_t1                  1              0              1                   21
# E3_t2                  2              0              1                   27
# E3_t3                  1              0              0                    0
# ...                  ...            ...            ...                  ...
# E6_t1                  3              0              1                    2
# E6_t2                  3              0              3                   73
# E6_t3                  0              0              2                    3
# E6_t4                  3              0              0                    0
# E6_t5                  0              0              0                    0
# E6_t6                  1              0              0                    0
# E6_t7                  3              0              9                   15
# E6_t8                  3              1             20                   42
# E6_t9                  3              0              6                   44
# T1_1_t10               1              0              0                    0
# T1_1_t11               1              0              0                    0
# T1_1_t12               4              1              2                   30
# T1_1_t1                3              0              1                    2
# T1_1_t2                1              0              2                   59
# T1_1_t3                1              0              1                   12
# T1_1_t4                1              0              1                   12
# T1_1_t5                0              0              1                    5
# T1_1_t6                4              0              0                    0
# T1_1_t7                2              0              0                    0
# T1_1_t8                0              0              3                    3
# T1_1_t9                2              0              0                    0
# T3_2_t1                2              0              0                    0
# T3_2_t2                2              0              0                    0
# T3_2_t3                0              0              0                    0
# T3_2_t4                1              0              0                    0
# T3_2_t5                0              0              0                    0
# T3_2_t6                3              0              1                    9
# T3_2_t7                1              0              0                    0
# T3_2_t8                0              0              0                    0
# T3_2_t9                1              0              0                    0
#
#           NUMBER_OF_JERK_FRAMES   TIME  NUMBER_OF_RINGDROP  VARIANCE  \
# VIDEO
# E1_t10                        0  11.96                   0  0.054081
# E1_t11                        0  12.96                   0  0.048060
# E1_t12                        0  20.96                   0  0.039564
# E1_t1                         6  19.96                   0  0.046704
# E1_t2                         0  10.68                   1  0.039239
# E1_t3                         3   8.96                   0  0.058930
# E1_t4                         5  16.84                   0  0.057878
# E1_t5                         3  11.00                   0  0.061005
# E1_t6                         0  12.96                   0  0.062915
# E1_t7                         0  17.76                   0  0.036587
# E1_t8                         0  12.92                   0  0.043536
# E1_t9                         0   7.64                   0  0.056178
# E2_t10                        0   9.56                   0  0.062549
# E2_t11                        0  20.84                   0  0.032915
# E2_t12                        0  27.52                   0  0.038665
# E2_t1                         0  20.00                   0  0.045962
# E2_t2                         0  19.84                   0  0.038167
# E2_t3                         0  11.68                   0  0.051923
# E2_t4                         0  17.68                   0  0.041324
# E2_t5                         0  11.84                   0  0.045975
# E2_t6                         0  17.84                   0  0.049078
# E2_t7                         0  26.88                   0  0.031914
# E2_t8                         0  16.00                   0  0.043168
# E2_t9                         0  19.68                   0  0.038293
# E3_t10                        0   8.76                   0  0.049619
# E3_t11                        0  15.64                   0  0.039081
# E3_t12                        0  14.80                   0  0.038331
# E3_t1                         0  18.00                   0  0.038430
# E3_t2                         0  18.96                   0  0.035355
# E3_t3                         1   8.76                   0  0.050410
# ...                         ...    ...                 ...       ...
# E6_t1                         0  29.00                   0  0.032234
# E6_t2                         3  30.00                   0  0.029066
# E6_t3                         0  21.72                   0  0.038567
# E6_t4                         7  30.60                   0  0.048801
# E6_t5                         1  24.88                   0  0.038650
# E6_t6                         1  22.88                   0  0.042202
# E6_t7                        11  37.76                   0  0.033367
# E6_t8                         3  30.84                   0  0.034198
# E6_t9                         0  28.84                   0  0.042553
# T1_1_t10                      3  35.72                   0  0.028309
# T1_1_t11                      4  44.72                   0  0.025481
# T1_1_t12                      8  48.60                   0  0.027744
# T1_1_t1                       1  45.00                   0  0.024380
# T1_1_t2                       0  52.88                   0  0.025881
# T1_1_t3                       0  31.76                   0  0.022310
# T1_1_t4                       0  31.76                   0  0.030346
# T1_1_t5                       3  62.60                   0  0.038191
# T1_1_t6                       9  49.72                   0  0.061726
# T1_1_t7                       2  34.80                   0  0.027907
# T1_1_t8                       5  47.76                   0  0.034554
# T1_1_t9                       2  58.76                   0  0.029407
# T3_2_t1                       1  23.00                   0  0.032407
# T3_2_t2                       0  15.96                   0  0.114105
# T3_2_t3                       0  12.60                   0  0.056364
# T3_2_t4                       1  15.60                   0  0.048022
# T3_2_t5                       0  13.72                   0  0.068251
# T3_2_t6                       1  20.76                   0  0.050889
# T3_2_t7                       0  24.60                   0  0.031587
# T3_2_t8                       2  28.60                   0  0.032994
# T3_2_t9                       4  13.76                   0  0.046281
#
#           ARC_LENGTH  CURVATURE_MAX_COUNT
# VIDEO
# E1_t10      2.801715                    1
# E1_t11      2.638573                    5
# E1_t12      3.522528                   10
# E1_t1       3.224847                    9
# E1_t2       1.886396                    7
# E1_t3       2.086997                    3
# E1_t4       3.858408                    7
# E1_t5       2.589191                    4
# E1_t6       3.272296                    4
# E1_t7       2.682000                    6
# E1_t8       2.290343                    7
# E1_t9       1.839921                    4
# E2_t10      2.444690                    4
# E2_t11      2.898186                    7
# E2_t12      4.367981                    7
# E2_t1       2.978475                    5
# E2_t2       3.055050                    9
# E2_t3       2.495409                    3
# E2_t4       2.960012                   10
# E2_t5       2.253309                    6
# E2_t6       3.644503                    5
# E2_t7       3.802464                   10
# E2_t8       2.840632                    6
# E2_t9       3.314057                    6
# E3_t10      1.857779                    4
# E3_t11      2.692479                    6
# E3_t12      2.200296                    7
# E3_t1       2.437788                    4
# E3_t2       2.700379                   13
# E3_t3       1.877165                    1
# ...              ...                  ...
# E6_t1       3.646246                   14
# E6_t2       3.444271                   21
# E6_t3       3.220092                    7
# E6_t4       5.866563                    6
# E6_t5       3.704197                   13
# E6_t6       3.974527                    9
# E6_t7       4.982067                   16
# E6_t8       4.618844                    9
# E6_t9       4.977824                    8
# T1_1_t10    4.218620                   13
# T1_1_t11    4.820924                   24
# T1_1_t12    5.529030                   23
# T1_1_t1     3.981488                   18
# T1_1_t2     5.428392                   38
# T1_1_t3     3.588757                   27
# T1_1_t4     4.188076                    7
# T1_1_t5     7.724986                   31
# T1_1_t6     8.987799                   22
# T1_1_t7     4.036103                   16
# T1_1_t8     6.700138                   22
# T1_1_t9     5.822720                   25
# T3_2_t1     2.981672                   10
# T3_2_t2     4.660140                    6
# T3_2_t3     2.991434                    4
# T3_2_t4     3.260845                    1
# T3_2_t5     3.902985                    2
# T3_2_t6     4.336099                    9
# T3_2_t7     3.220852                    9
# T3_2_t8     3.925871                   18
# T3_2_t9     2.659368                    6
#
# [93 rows x 10 columns]

# %%
# normalized_data_gt=(data_gt-data_gt.min())/(data_gt.max()-data_gt.min())

from sklearn import preprocessing

# Get column names first
names = data_gt.columns
# Create the Scaler object
scaler = preprocessing.StandardScaler()
# Fit your data on the scaler object
scaled_df = scaler.fit_transform(data_gt)
normalized_data_gt = pd.DataFrame(scaled_df, columns=names, index= index)

# %%
normalized_data_gt
# Out:
#           NUMBER_OF_HITS  HIT_INTENSITY  NUMBER_OF_TUG  TOTAL_FRAMES_IN_TUG  \
# VIDEO
# E1_t10          0.383137      -0.306786       0.200997             0.342397
# E1_t11          0.383137      -0.306786      -0.188435             0.173020
# E1_t12          0.383137      -0.306786       0.590429             0.469429
# E1_t1           0.383137       3.259601      -0.188435            -0.250423
# E1_t2          -1.542903      -0.306786      -0.188435            -0.504489
# E1_t3          -1.542903      -0.306786       0.200997             0.173020
# E1_t4          -0.579883      -0.306786      -0.188435             0.088331
# E1_t5          -0.579883      -0.306786      -0.188435             0.003643
# E1_t6           0.383137      -0.306786      -0.188435             0.045987
# E1_t7           0.383137       3.259601      -0.188435             0.681151
# E1_t8          -0.579883      -0.306786       0.590429            -0.123390
# E1_t9          -0.579883      -0.306786      -0.188435             0.130675
# E2_t10         -1.542903      -0.306786      -0.577866            -0.631521
# E2_t11          0.383137      -0.306786      -0.188435            -0.292767
# E2_t12         -0.579883       3.259601       0.590429             0.469429
# E2_t1           0.383137      -0.306786      -0.188435            -0.419800
# E2_t2           0.383137      -0.306786       0.200997             1.146938
# E2_t3           0.383137      -0.306786      -0.188435             0.342397
# E2_t4          -0.579883      -0.306786       0.590429             0.130675
# E2_t5          -0.579883      -0.306786      -0.577866            -0.631521
# E2_t6          -0.579883      -0.306786       0.200997             0.935216
# E2_t7           0.383137      -0.306786       0.979860             2.586643
# E2_t8           0.383137      -0.306786      -0.577866            -0.631521
# E2_t9           0.383137      -0.306786      -0.577866            -0.631521
# E3_t10         -1.542903      -0.306786      -0.577866            -0.631521
# E3_t11          0.383137      -0.306786       0.200997             0.384741
# E3_t12          0.383137      -0.306786      -0.577866            -0.631521
# E3_t1          -0.579883      -0.306786      -0.188435             0.257708
# E3_t2           0.383137      -0.306786      -0.188435             0.511774
# E3_t3          -0.579883      -0.306786      -0.577866            -0.631521
# ...                  ...            ...            ...                  ...
# E6_t1           1.346157      -0.306786      -0.188435            -0.546833
# E6_t2           1.346157      -0.306786       0.590429             2.459610
# E6_t3          -1.542903      -0.306786       0.200997            -0.504489
# E6_t4           1.346157      -0.306786      -0.577866            -0.631521
# E6_t5          -1.542903      -0.306786      -0.577866            -0.631521
# E6_t6          -0.579883      -0.306786      -0.577866            -0.631521
# E6_t7           1.346157      -0.306786       2.927019             0.003643
# E6_t8           1.346157       3.259601       7.210767             1.146938
# E6_t9           1.346157      -0.306786       1.758724             1.231626
# T1_1_t10       -0.579883      -0.306786      -0.577866            -0.631521
# T1_1_t11       -0.579883      -0.306786      -0.577866            -0.631521
# T1_1_t12        2.309177       3.259601       0.200997             0.638807
# T1_1_t1         1.346157      -0.306786      -0.188435            -0.546833
# T1_1_t2        -0.579883      -0.306786       0.200997             1.866790
# T1_1_t3        -0.579883      -0.306786      -0.188435            -0.123390
# T1_1_t4        -0.579883      -0.306786      -0.188435            -0.123390
# T1_1_t5        -1.542903      -0.306786      -0.188435            -0.419800
# T1_1_t6         2.309177      -0.306786      -0.577866            -0.631521
# T1_1_t7         0.383137      -0.306786      -0.577866            -0.631521
# T1_1_t8        -1.542903      -0.306786       0.590429            -0.504489
# T1_1_t9         0.383137      -0.306786      -0.577866            -0.631521
# T3_2_t1         0.383137      -0.306786      -0.577866            -0.631521
# T3_2_t2         0.383137      -0.306786      -0.577866            -0.631521
# T3_2_t3        -1.542903      -0.306786      -0.577866            -0.631521
# T3_2_t4        -0.579883      -0.306786      -0.577866            -0.631521
# T3_2_t5        -1.542903      -0.306786      -0.577866            -0.631521
# T3_2_t6         1.346157      -0.306786      -0.188435            -0.250423
# T3_2_t7        -0.579883      -0.306786      -0.577866            -0.631521
# T3_2_t8        -1.542903      -0.306786      -0.577866            -0.631521
# T3_2_t9        -0.579883      -0.306786      -0.577866            -0.631521
#
#           NUMBER_OF_JERK_FRAMES      TIME  NUMBER_OF_RINGDROP  VARIANCE  \
# VIDEO
# E1_t10                -0.619658 -0.913464           -0.104257  0.515299
# E1_t11                -0.619658 -0.828020           -0.104257  0.128980
# E1_t12                -0.619658 -0.144465           -0.104257 -0.416128
# E1_t1                  0.815069 -0.229909           -0.104257  0.042006
# E1_t2                 -0.619658 -1.022833            9.591663 -0.436955
# E1_t3                  0.097705 -1.169797           -0.104257  0.826415
# E1_t4                  0.575948 -0.496496           -0.104257  0.758909
# E1_t5                  0.097705 -0.995490           -0.104257  0.959590
# E1_t6                 -0.619658 -0.828020           -0.104257  1.082084
# E1_t7                 -0.619658 -0.417887           -0.104257 -0.607126
# E1_t8                 -0.619658 -0.831437           -0.104257 -0.161269
# E1_t9                 -0.619658 -1.282583           -0.104257  0.649854
# E2_t10                -0.619658 -1.118530           -0.104257  1.058658
# E2_t11                -0.619658 -0.154718           -0.104257 -0.842715
# E2_t12                -0.619658  0.416049           -0.104257 -0.473779
# E2_t1                 -0.619658 -0.226492           -0.104257 -0.005607
# E2_t2                 -0.619658 -0.240163           -0.104257 -0.505743
# E2_t3                 -0.619658 -0.937388           -0.104257  0.376838
# E2_t4                 -0.619658 -0.424722           -0.104257 -0.303173
# E2_t5                 -0.619658 -0.923717           -0.104257 -0.004754
# E2_t6                 -0.619658 -0.411051           -0.104257  0.194297
# E2_t7                 -0.619658  0.361365           -0.104257 -0.906974
# E2_t8                 -0.619658 -0.568269           -0.104257 -0.184887
# E2_t9                 -0.619658 -0.253834           -0.104257 -0.497695
# E3_t10                -0.619658 -1.186886           -0.104257  0.229009
# E3_t11                -0.619658 -0.599029           -0.104257 -0.447132
# E3_t12                -0.619658 -0.670802           -0.104257 -0.495263
# E3_t1                 -0.619658 -0.397380           -0.104257 -0.488894
# E3_t2                 -0.619658 -0.315354           -0.104257 -0.686197
# E3_t3                 -0.380537 -1.186886           -0.104257  0.279775
# ...                         ...       ...                 ...       ...
# E6_t1                 -0.619658  0.542507           -0.104257 -0.886418
# E6_t2                  0.097705  0.627951           -0.104257 -1.089695
# E6_t3                 -0.619658 -0.079528           -0.104257 -0.480101
# E6_t4                  1.054190  0.679218           -0.104257  0.176529
# E6_t5                 -0.380537  0.190476           -0.104257 -0.474793
# E6_t6                 -0.380537  0.019588           -0.104257 -0.246845
# E6_t7                  2.010675  1.290999           -0.104257 -0.813749
# E6_t8                  0.097705  0.699725           -0.104257 -0.760395
# E6_t9                 -0.619658  0.528836           -0.104257 -0.224319
# T1_1_t10               0.097705  1.116693           -0.104257 -1.138244
# T1_1_t11               0.336827  1.885691           -0.104257 -1.319727
# T1_1_t12               1.293311  2.217215           -0.104257 -1.174543
# T1_1_t1               -0.380537  1.909616           -0.104257 -1.390392
# T1_1_t2               -0.619658  2.582917           -0.104257 -1.294068
# T1_1_t3               -0.619658  0.778333           -0.104257 -1.523160
# T1_1_t4               -0.619658  0.778333           -0.104257 -1.007568
# T1_1_t5                0.097705  3.413435           -0.104257 -0.504209
# T1_1_t6                1.532432  2.312913           -0.104257  1.005797
# T1_1_t7               -0.141416  1.038084           -0.104257 -1.164090
# T1_1_t8                0.575948  2.145442           -0.104257 -0.737570
# T1_1_t9               -0.141416  3.085329           -0.104257 -1.067839
# T3_2_t1               -0.380537  0.029841           -0.104257 -0.875305
# T3_2_t2               -0.619658 -0.571687           -0.104257  4.366558
# T3_2_t3               -0.619658 -0.858780           -0.104257  0.661814
# T3_2_t4               -0.380537 -0.602447           -0.104257  0.126524
# T3_2_t5               -0.619658 -0.763082           -0.104257  1.424463
# T3_2_t6               -0.380537 -0.161554           -0.104257  0.310485
# T3_2_t7               -0.619658  0.166552           -0.104257 -0.927970
# T3_2_t8               -0.141416  0.508329           -0.104257 -0.837656
# T3_2_t9                0.336827 -0.759664           -0.104257  0.014843
#
#           ARC_LENGTH  CURVATURE_MAX_COUNT
# VIDEO
# E1_t10     -0.676353            -1.175085
# E1_t11     -0.804056            -0.619645
# E1_t12     -0.112122             0.074656
# E1_t1      -0.345137            -0.064204
# E1_t2      -1.392838            -0.341924
# E1_t3      -1.235813            -0.897365
# E1_t4       0.150795            -0.341924
# E1_t5      -0.842710            -0.758505
# E1_t6      -0.307996            -0.758505
# E1_t7      -0.770062            -0.480784
# E1_t8      -1.076640            -0.341924
# E1_t9      -1.429217            -0.758505
# E2_t10     -0.955821            -0.758505
# E2_t11     -0.600838            -0.341924
# E2_t12      0.549674            -0.341924
# E2_t1      -0.537990            -0.619645
# E2_t2      -0.478050            -0.064204
# E2_t3      -0.916121            -0.897365
# E2_t4      -0.552443             0.074656
# E2_t5      -1.105629            -0.480784
# E2_t6      -0.016643            -0.619645
# E2_t7       0.107004             0.074656
# E2_t8      -0.645890            -0.480784
# E2_t9      -0.275307            -0.480784
# E3_t10     -1.415239            -0.758505
# E3_t11     -0.761860            -0.480784
# E3_t12     -1.147126            -0.341924
# E3_t1      -0.961224            -0.758505
# E3_t2      -0.755675             0.491236
# E3_t3      -1.400063            -1.175085
# ...              ...                  ...
# E6_t1      -0.015279             0.630096
# E6_t2      -0.173378             1.602117
# E6_t3      -0.348859            -0.341924
# E6_t4       1.722721            -0.480784
# E6_t5       0.030084             0.491236
# E6_t6       0.241690            -0.064204
# E6_t7       1.030363             0.907817
# E6_t8       0.746042            -0.064204
# E6_t9       1.027041            -0.203064
# T1_1_t10    0.432759             0.491236
# T1_1_t11    0.904225             2.018698
# T1_1_t12    1.458510             1.879837
# T1_1_t1     0.247139             1.185537
# T1_1_t2     1.379733             3.962739
# T1_1_t3    -0.060279             2.435278
# T1_1_t4     0.408850            -0.341924
# T1_1_t5     3.177440             2.990718
# T1_1_t6     4.165933             1.740977
# T1_1_t7     0.289890             0.907817
# T1_1_t8     2.375219             1.740977
# T1_1_t9     1.688402             2.157558
# T3_2_t1    -0.535488             0.074656
# T3_2_t2     0.778368            -0.480784
# T3_2_t3    -0.527846            -0.758505
# T3_2_t4    -0.316959            -1.175085
# T3_2_t5     0.185689            -1.036225
# T3_2_t6     0.524718            -0.064204
# T3_2_t7    -0.348265            -0.064204
# T3_2_t8     0.203603             1.185537
# T3_2_t9    -0.787778            -0.480784
#
# [93 rows x 10 columns]

# %%
df_expert = pd.read_csv('./expert_scores_trainee_scores.csv',  index_col="Video")

# %%
df_expert
# Out:
#           Hand-eye Coordination  Instrument-Tissue Manipulation  Dexterity  \
# Video
# E1_t1                         3                               3          3
# E1_t2                         3                               3          3
# E1_t3                         4                               3          4
# E1_t4                         3                               2          4
# E1_t5                         3                               3          4
# E1_t6                         3                               3          4
# E1_t7                         4                               4          4
# E1_t8                         3                               3          4
# E1_t9                         4                               4          4
# E1_t10                        4                               3          4
# E1_t11                        4                               3          4
# E1_t12                        4                               2          4
# E2_t1                         4                               4          4
# E2_t2                         4                               3          4
# E2_t3                         4                               4          4
# E2_t4                         4                               3          4
# E2_t5                         4                               4          4
# E2_t6                         3                               3          4
# E2_t7                         3                               3          4
# E2_t8                         4                               4          4
# E2_t9                         4                               4          4
# E2_t10                        4                               4          4
# E2_t11                        4                               3          4
# E2_t12                        3                               3          4
# E3_t1                         4                               3          4
# E3_t2                         4                               3          4
# E3_t3                         4                               4          4
# E3_t4                         4                               3          4
# E3_t5                         4                               3          4
# E3_t6                         4                               3          4
# ...                         ...                             ...        ...
# E6_t4                         3                               4          4
# E6_t5                         4                               4          4
# E6_t6                         3                               3          4
# E6_t7                         3                               3          2
# E6_t8                         4                               3          4
# E6_t9                         3                               3          3
# E6_t10                        4                               3          4
# E6_t11                        3                               3          3
# E6_t12                        4                               3          4
# T1_1_t1                       2                               2          3
# T1_1_t2                       2                               2          3
# T1_1_t3                       2                               2          2
# T1_1_t4                       2                               2          2
# T1_1_t5                       1                               3          3
# T1_1_t6                       1                               2          2
# T1_1_t7                       1                               1          1
# T1_1_t8                       1                               1          1
# T1_1_t9                       1                               1          2
# T1_1_t10                      2                               3          2
# T1_1_t11                      3                               3          3
# T1_1_t12                      2                               2          3
# T3_2_t1                       3                               3          3
# T3_2_t2                       3                               3          3
# T3_2_t3                       3                               3          4
# T3_2_t4                       3                               3          3
# T3_2_t5                       4                               3          4
# T3_2_t6                       3                               3          3
# T3_2_t7                       3                               3          3
# T3_2_t8                       3                               3          2
# T3_2_t9                       3                               3          3
#
#           Flow of procedure  Effectualness  Overall
# Video
# E1_t1                     3              4       15
# E1_t2                     2              1        8
# E1_t3                     4              4       18
# E1_t4                     4              4       16
# E1_t5                     4              4       17
# E1_t6                     4              4       17
# E1_t7                     4              4       20
# E1_t8                     4              4       17
# E1_t9                     4              4       20
# E1_t10                    4              4       19
# E1_t11                    4              4       19
# E1_t12                    4              4       18
# E2_t1                     4              4       19
# E2_t2                     4              4       17
# E2_t3                     4              4       20
# E2_t4                     4              4       17
# E2_t5                     4              4       20
# E2_t6                     4              4       17
# E2_t7                     4              4       17
# E2_t8                     4              4       20
# E2_t9                     4              4       20
# E2_t10                    4              4       20
# E2_t11                    4              4       18
# E2_t12                    4              4       17
# E3_t1                     4              4       19
# E3_t2                     4              4       19
# E3_t3                     4              4       20
# E3_t4                     4              4       18
# E3_t5                     4              4       19
# E3_t6                     4              4       19
# ...                     ...            ...      ...
# E6_t4                     4              4       19
# E6_t5                     4              4       20
# E6_t6                     4              4       18
# E6_t7                     3              4       14
# E6_t8                     4              4       18
# E6_t9                     3              4       15
# E6_t10                    4              4       19
# E6_t11                    3              4       15
# E6_t12                    4              4       18
# T1_1_t1                   3              4       11
# T1_1_t2                   3              4       10
# T1_1_t3                   3              4       10
# T1_1_t4                   3              4       11
# T1_1_t5                   3              4       10
# T1_1_t6                   2              4        8
# T1_1_t7                   2              4        7
# T1_1_t8                   1              4        5
# T1_1_t9                   3              4        8
# T1_1_t10                  3              4       11
# T1_1_t11                  4              4       13
# T1_1_t12                  3              4       11
# T3_2_t1                   4              4       15
# T3_2_t2                   4              4       15
# T3_2_t3                   4              4       16
# T3_2_t4                   4              4       15
# T3_2_t5                   4              4       16
# T3_2_t6                   4              4       13
# T3_2_t7                   4              4       13
# T3_2_t8                   2              4       10
# T3_2_t9                   4              4       13
#
# [93 rows x 6 columns]

# %%
print(type(normalized_data_gt))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
JOINT = normalized_data_gt.join(df_expert)

# %%
JOINT
# Out:
#           NUMBER_OF_HITS  HIT_INTENSITY  NUMBER_OF_TUG  TOTAL_FRAMES_IN_TUG  \
# VIDEO
# E1_t10          0.383137      -0.306786       0.200997             0.342397
# E1_t11          0.383137      -0.306786      -0.188435             0.173020
# E1_t12          0.383137      -0.306786       0.590429             0.469429
# E1_t1           0.383137       3.259601      -0.188435            -0.250423
# E1_t2          -1.542903      -0.306786      -0.188435            -0.504489
# E1_t3          -1.542903      -0.306786       0.200997             0.173020
# E1_t4          -0.579883      -0.306786      -0.188435             0.088331
# E1_t5          -0.579883      -0.306786      -0.188435             0.003643
# E1_t6           0.383137      -0.306786      -0.188435             0.045987
# E1_t7           0.383137       3.259601      -0.188435             0.681151
# E1_t8          -0.579883      -0.306786       0.590429            -0.123390
# E1_t9          -0.579883      -0.306786      -0.188435             0.130675
# E2_t10         -1.542903      -0.306786      -0.577866            -0.631521
# E2_t11          0.383137      -0.306786      -0.188435            -0.292767
# E2_t12         -0.579883       3.259601       0.590429             0.469429
# E2_t1           0.383137      -0.306786      -0.188435            -0.419800
# E2_t2           0.383137      -0.306786       0.200997             1.146938
# E2_t3           0.383137      -0.306786      -0.188435             0.342397
# E2_t4          -0.579883      -0.306786       0.590429             0.130675
# E2_t5          -0.579883      -0.306786      -0.577866            -0.631521
# E2_t6          -0.579883      -0.306786       0.200997             0.935216
# E2_t7           0.383137      -0.306786       0.979860             2.586643
# E2_t8           0.383137      -0.306786      -0.577866            -0.631521
# E2_t9           0.383137      -0.306786      -0.577866            -0.631521
# E3_t10         -1.542903      -0.306786      -0.577866            -0.631521
# E3_t11          0.383137      -0.306786       0.200997             0.384741
# E3_t12          0.383137      -0.306786      -0.577866            -0.631521
# E3_t1          -0.579883      -0.306786      -0.188435             0.257708
# E3_t2           0.383137      -0.306786      -0.188435             0.511774
# E3_t3          -0.579883      -0.306786      -0.577866            -0.631521
# ...                  ...            ...            ...                  ...
# E6_t1           1.346157      -0.306786      -0.188435            -0.546833
# E6_t2           1.346157      -0.306786       0.590429             2.459610
# E6_t3          -1.542903      -0.306786       0.200997            -0.504489
# E6_t4           1.346157      -0.306786      -0.577866            -0.631521
# E6_t5          -1.542903      -0.306786      -0.577866            -0.631521
# E6_t6          -0.579883      -0.306786      -0.577866            -0.631521
# E6_t7           1.346157      -0.306786       2.927019             0.003643
# E6_t8           1.346157       3.259601       7.210767             1.146938
# E6_t9           1.346157      -0.306786       1.758724             1.231626
# T1_1_t10       -0.579883      -0.306786      -0.577866            -0.631521
# T1_1_t11       -0.579883      -0.306786      -0.577866            -0.631521
# T1_1_t12        2.309177       3.259601       0.200997             0.638807
# T1_1_t1         1.346157      -0.306786      -0.188435            -0.546833
# T1_1_t2        -0.579883      -0.306786       0.200997             1.866790
# T1_1_t3        -0.579883      -0.306786      -0.188435            -0.123390
# T1_1_t4        -0.579883      -0.306786      -0.188435            -0.123390
# T1_1_t5        -1.542903      -0.306786      -0.188435            -0.419800
# T1_1_t6         2.309177      -0.306786      -0.577866            -0.631521
# T1_1_t7         0.383137      -0.306786      -0.577866            -0.631521
# T1_1_t8        -1.542903      -0.306786       0.590429            -0.504489
# T1_1_t9         0.383137      -0.306786      -0.577866            -0.631521
# T3_2_t1         0.383137      -0.306786      -0.577866            -0.631521
# T3_2_t2         0.383137      -0.306786      -0.577866            -0.631521
# T3_2_t3        -1.542903      -0.306786      -0.577866            -0.631521
# T3_2_t4        -0.579883      -0.306786      -0.577866            -0.631521
# T3_2_t5        -1.542903      -0.306786      -0.577866            -0.631521
# T3_2_t6         1.346157      -0.306786      -0.188435            -0.250423
# T3_2_t7        -0.579883      -0.306786      -0.577866            -0.631521
# T3_2_t8        -1.542903      -0.306786      -0.577866            -0.631521
# T3_2_t9        -0.579883      -0.306786      -0.577866            -0.631521
#
#           NUMBER_OF_JERK_FRAMES      TIME  NUMBER_OF_RINGDROP  VARIANCE  \
# VIDEO
# E1_t10                -0.619658 -0.913464           -0.104257  0.515299
# E1_t11                -0.619658 -0.828020           -0.104257  0.128980
# E1_t12                -0.619658 -0.144465           -0.104257 -0.416128
# E1_t1                  0.815069 -0.229909           -0.104257  0.042006
# E1_t2                 -0.619658 -1.022833            9.591663 -0.436955
# E1_t3                  0.097705 -1.169797           -0.104257  0.826415
# E1_t4                  0.575948 -0.496496           -0.104257  0.758909
# E1_t5                  0.097705 -0.995490           -0.104257  0.959590
# E1_t6                 -0.619658 -0.828020           -0.104257  1.082084
# E1_t7                 -0.619658 -0.417887           -0.104257 -0.607126
# E1_t8                 -0.619658 -0.831437           -0.104257 -0.161269
# E1_t9                 -0.619658 -1.282583           -0.104257  0.649854
# E2_t10                -0.619658 -1.118530           -0.104257  1.058658
# E2_t11                -0.619658 -0.154718           -0.104257 -0.842715
# E2_t12                -0.619658  0.416049           -0.104257 -0.473779
# E2_t1                 -0.619658 -0.226492           -0.104257 -0.005607
# E2_t2                 -0.619658 -0.240163           -0.104257 -0.505743
# E2_t3                 -0.619658 -0.937388           -0.104257  0.376838
# E2_t4                 -0.619658 -0.424722           -0.104257 -0.303173
# E2_t5                 -0.619658 -0.923717           -0.104257 -0.004754
# E2_t6                 -0.619658 -0.411051           -0.104257  0.194297
# E2_t7                 -0.619658  0.361365           -0.104257 -0.906974
# E2_t8                 -0.619658 -0.568269           -0.104257 -0.184887
# E2_t9                 -0.619658 -0.253834           -0.104257 -0.497695
# E3_t10                -0.619658 -1.186886           -0.104257  0.229009
# E3_t11                -0.619658 -0.599029           -0.104257 -0.447132
# E3_t12                -0.619658 -0.670802           -0.104257 -0.495263
# E3_t1                 -0.619658 -0.397380           -0.104257 -0.488894
# E3_t2                 -0.619658 -0.315354           -0.104257 -0.686197
# E3_t3                 -0.380537 -1.186886           -0.104257  0.279775
# ...                         ...       ...                 ...       ...
# E6_t1                 -0.619658  0.542507           -0.104257 -0.886418
# E6_t2                  0.097705  0.627951           -0.104257 -1.089695
# E6_t3                 -0.619658 -0.079528           -0.104257 -0.480101
# E6_t4                  1.054190  0.679218           -0.104257  0.176529
# E6_t5                 -0.380537  0.190476           -0.104257 -0.474793
# E6_t6                 -0.380537  0.019588           -0.104257 -0.246845
# E6_t7                  2.010675  1.290999           -0.104257 -0.813749
# E6_t8                  0.097705  0.699725           -0.104257 -0.760395
# E6_t9                 -0.619658  0.528836           -0.104257 -0.224319
# T1_1_t10               0.097705  1.116693           -0.104257 -1.138244
# T1_1_t11               0.336827  1.885691           -0.104257 -1.319727
# T1_1_t12               1.293311  2.217215           -0.104257 -1.174543
# T1_1_t1               -0.380537  1.909616           -0.104257 -1.390392
# T1_1_t2               -0.619658  2.582917           -0.104257 -1.294068
# T1_1_t3               -0.619658  0.778333           -0.104257 -1.523160
# T1_1_t4               -0.619658  0.778333           -0.104257 -1.007568
# T1_1_t5                0.097705  3.413435           -0.104257 -0.504209
# T1_1_t6                1.532432  2.312913           -0.104257  1.005797
# T1_1_t7               -0.141416  1.038084           -0.104257 -1.164090
# T1_1_t8                0.575948  2.145442           -0.104257 -0.737570
# T1_1_t9               -0.141416  3.085329           -0.104257 -1.067839
# T3_2_t1               -0.380537  0.029841           -0.104257 -0.875305
# T3_2_t2               -0.619658 -0.571687           -0.104257  4.366558
# T3_2_t3               -0.619658 -0.858780           -0.104257  0.661814
# T3_2_t4               -0.380537 -0.602447           -0.104257  0.126524
# T3_2_t5               -0.619658 -0.763082           -0.104257  1.424463
# T3_2_t6               -0.380537 -0.161554           -0.104257  0.310485
# T3_2_t7               -0.619658  0.166552           -0.104257 -0.927970
# T3_2_t8               -0.141416  0.508329           -0.104257 -0.837656
# T3_2_t9                0.336827 -0.759664           -0.104257  0.014843
#
#           ARC_LENGTH  CURVATURE_MAX_COUNT  Hand-eye Coordination  \
# VIDEO
# E1_t10     -0.676353            -1.175085                      4
# E1_t11     -0.804056            -0.619645                      4
# E1_t12     -0.112122             0.074656                      4
# E1_t1      -0.345137            -0.064204                      3
# E1_t2      -1.392838            -0.341924                      3
# E1_t3      -1.235813            -0.897365                      4
# E1_t4       0.150795            -0.341924                      3
# E1_t5      -0.842710            -0.758505                      3
# E1_t6      -0.307996            -0.758505                      3
# E1_t7      -0.770062            -0.480784                      4
# E1_t8      -1.076640            -0.341924                      3
# E1_t9      -1.429217            -0.758505                      4
# E2_t10     -0.955821            -0.758505                      4
# E2_t11     -0.600838            -0.341924                      4
# E2_t12      0.549674            -0.341924                      3
# E2_t1      -0.537990            -0.619645                      4
# E2_t2      -0.478050            -0.064204                      4
# E2_t3      -0.916121            -0.897365                      4
# E2_t4      -0.552443             0.074656                      4
# E2_t5      -1.105629            -0.480784                      4
# E2_t6      -0.016643            -0.619645                      3
# E2_t7       0.107004             0.074656                      3
# E2_t8      -0.645890            -0.480784                      4
# E2_t9      -0.275307            -0.480784                      4
# E3_t10     -1.415239            -0.758505                      4
# E3_t11     -0.761860            -0.480784                      4
# E3_t12     -1.147126            -0.341924                      4
# E3_t1      -0.961224            -0.758505                      4
# E3_t2      -0.755675             0.491236                      4
# E3_t3      -1.400063            -1.175085                      4
# ...              ...                  ...                    ...
# E6_t1      -0.015279             0.630096                      3
# E6_t2      -0.173378             1.602117                      3
# E6_t3      -0.348859            -0.341924                      4
# E6_t4       1.722721            -0.480784                      3
# E6_t5       0.030084             0.491236                      4
# E6_t6       0.241690            -0.064204                      3
# E6_t7       1.030363             0.907817                      3
# E6_t8       0.746042            -0.064204                      4
# E6_t9       1.027041            -0.203064                      3
# T1_1_t10    0.432759             0.491236                      2
# T1_1_t11    0.904225             2.018698                      3
# T1_1_t12    1.458510             1.879837                      2
# T1_1_t1     0.247139             1.185537                      2
# T1_1_t2     1.379733             3.962739                      2
# T1_1_t3    -0.060279             2.435278                      2
# T1_1_t4     0.408850            -0.341924                      2
# T1_1_t5     3.177440             2.990718                      1
# T1_1_t6     4.165933             1.740977                      1
# T1_1_t7     0.289890             0.907817                      1
# T1_1_t8     2.375219             1.740977                      1
# T1_1_t9     1.688402             2.157558                      1
# T3_2_t1    -0.535488             0.074656                      3
# T3_2_t2     0.778368            -0.480784                      3
# T3_2_t3    -0.527846            -0.758505                      3
# T3_2_t4    -0.316959            -1.175085                      3
# T3_2_t5     0.185689            -1.036225                      4
# T3_2_t6     0.524718            -0.064204                      3
# T3_2_t7    -0.348265            -0.064204                      3
# T3_2_t8     0.203603             1.185537                      3
# T3_2_t9    -0.787778            -0.480784                      3
#
#           Instrument-Tissue Manipulation  Dexterity  Flow of procedure  \
# VIDEO
# E1_t10                                 3          4                  4
# E1_t11                                 3          4                  4
# E1_t12                                 2          4                  4
# E1_t1                                  3          3                  3
# E1_t2                                  3          3                  2
# E1_t3                                  3          4                  4
# E1_t4                                  2          4                  4
# E1_t5                                  3          4                  4
# E1_t6                                  3          4                  4
# E1_t7                                  4          4                  4
# E1_t8                                  3          4                  4
# E1_t9                                  4          4                  4
# E2_t10                                 4          4                  4
# E2_t11                                 3          4                  4
# E2_t12                                 3          4                  4
# E2_t1                                  4          4                  4
# E2_t2                                  3          4                  4
# E2_t3                                  4          4                  4
# E2_t4                                  3          4                  4
# E2_t5                                  4          4                  4
# E2_t6                                  3          4                  4
# E2_t7                                  3          4                  4
# E2_t8                                  4          4                  4
# E2_t9                                  4          4                  4
# E3_t10                                 3          4                  4
# E3_t11                                 3          3                  4
# E3_t12                                 4          4                  4
# E3_t1                                  3          4                  4
# E3_t2                                  3          4                  4
# E3_t3                                  4          4                  4
# ...                                  ...        ...                ...
# E6_t1                                  3          4                  4
# E6_t2                                  2          3                  4
# E6_t3                                  4          4                  4
# E6_t4                                  4          4                  4
# E6_t5                                  4          4                  4
# E6_t6                                  3          4                  4
# E6_t7                                  3          2                  3
# E6_t8                                  3          4                  4
# E6_t9                                  3          3                  3
# T1_1_t10                               3          2                  3
# T1_1_t11                               3          3                  4
# T1_1_t12                               2          3                  3
# T1_1_t1                                2          3                  3
# T1_1_t2                                2          3                  3
# T1_1_t3                                2          2                  3
# T1_1_t4                                2          2                  3
# T1_1_t5                                3          3                  3
# T1_1_t6                                2          2                  2
# T1_1_t7                                1          1                  2
# T1_1_t8                                1          1                  1
# T1_1_t9                                1          2                  3
# T3_2_t1                                3          3                  4
# T3_2_t2                                3          3                  4
# T3_2_t3                                3          4                  4
# T3_2_t4                                3          3                  4
# T3_2_t5                                3          4                  4
# T3_2_t6                                3          3                  4
# T3_2_t7                                3          3                  4
# T3_2_t8                                3          2                  2
# T3_2_t9                                3          3                  4
#
#           Effectualness  Overall
# VIDEO
# E1_t10                4       19
# E1_t11                4       19
# E1_t12                4       18
# E1_t1                 4       15
# E1_t2                 1        8
# E1_t3                 4       18
# E1_t4                 4       16
# E1_t5                 4       17
# E1_t6                 4       17
# E1_t7                 4       20
# E1_t8                 4       17
# E1_t9                 4       20
# E2_t10                4       20
# E2_t11                4       18
# E2_t12                4       17
# E2_t1                 4       19
# E2_t2                 4       17
# E2_t3                 4       20
# E2_t4                 4       17
# E2_t5                 4       20
# E2_t6                 4       17
# E2_t7                 4       17
# E2_t8                 4       20
# E2_t9                 4       20
# E3_t10                4       19
# E3_t11                4       17
# E3_t12                4       20
# E3_t1                 4       19
# E3_t2                 4       19
# E3_t3                 4       20
# ...                 ...      ...
# E6_t1                 4       18
# E6_t2                 4       16
# E6_t3                 4       20
# E6_t4                 4       19
# E6_t5                 4       20
# E6_t6                 4       18
# E6_t7                 4       14
# E6_t8                 4       18
# E6_t9                 4       15
# T1_1_t10              4       11
# T1_1_t11              4       13
# T1_1_t12              4       11
# T1_1_t1               4       11
# T1_1_t2               4       10
# T1_1_t3               4       10
# T1_1_t4               4       11
# T1_1_t5               4       10
# T1_1_t6               4        8
# T1_1_t7               4        7
# T1_1_t8               4        5
# T1_1_t9               4        8
# T3_2_t1               4       15
# T3_2_t2               4       15
# T3_2_t3               4       16
# T3_2_t4               4       15
# T3_2_t5               4       16
# T3_2_t6               4       13
# T3_2_t7               4       13
# T3_2_t8               4       10
# T3_2_t9               4       13
#
# [93 rows x 16 columns]

# %%
JOINT.hist(color='g', alpha=0.6, bins=10, layout=(4,4), figsize=(20,9))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f5d63079ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d630c62e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d63002668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62fa4cf8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62f533c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62f53400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62f2f128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62ed77b8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62f00e48>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62eb2518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62e57ba8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62e8b278>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62e32908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62ddaf98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62e0b668>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f5d62db7cf8>]],
#       dtype=object)

# %%
covMatrix = pd.DataFrame.corr(JOINT)

# %%
import seaborn as sn
f, ax = plt.subplots(figsize=(20, 11))

ax = sn.heatmap(covMatrix, annot=True, fmt='g')
plt.show()

# %%
JOINT.columns
# Out:
# Index(['NUMBER_OF_HITS', 'HIT_INTENSITY', 'NUMBER_OF_TUG',
#        'TOTAL_FRAMES_IN_TUG', 'NUMBER_OF_JERK_FRAMES', 'TIME',
#        'NUMBER_OF_RINGDROP', 'VARIANCE', 'ARC_LENGTH', 'CURVATURE_MAX_COUNT',
#        'Hand-eye Coordination', 'Instrument-Tissue Manipulation', 'Dexterity',
#        'Flow of procedure', 'Effectualness', 'Overall'],
#       dtype='object')

# %%
from sklearn.model_selection import cross_val_score
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split,StratifiedShuffleSplit
from sklearn.preprocessing import StandardScaler

from sklearn.neural_network import MLPClassifier, MLPRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor

from sklearn.svm import SVC, SVR
from sklearn.gaussian_process import GaussianProcessClassifier, GaussianProcessRegressor
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor , AdaBoostClassifier, AdaBoostRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

from sklearn.metrics import mean_squared_error, accuracy_score, r2_score

from sklearn.metrics import label_ranking_loss 

from sklearn.model_selection import GridSearchCV
import random
from scipy.stats import pearsonr

from sklearn.metrics import make_scorer
from sklearn.metrics import classification_report
from sklearn.model_selection import cross_val_predict
from sklearn.utils import resample

# %%
names = ["Nearest Neighbors", "Linear SVM", "RBF SVM",
 "Decision Tree", "Random Forest"] # "Neural Net", "Gaussian Process", "AdaBoost", "Naive Bayes", "QDA"]

classifiers = [
    KNeighborsClassifier(),
    SVC(), #gamma=2, C=1
    SVC(), #kernel="linear", C=0.025
    DecisionTreeClassifier(),
    RandomForestClassifier()]
#     MLPClassifier(alpha=1, max_iter=1000),
#     GaussianProcessClassifier(1.0 * RBF(1.0)),
#     AdaBoostClassifier(),
#     GaussianNB(),
#     QuadraticDiscriminantAnalysis()]
params_classifiers = [
    {"n_neighbors":[3,4,5], "algorithm" :["auto", "ball_tree", "kd_tree", "brute"]},
    #{"n_neighbors":[3], "algorithm" :["auto"]},
    {'kernel': ['rbf'], 'gamma': [1,1e-1, 1e-2, 1e-3, 1e-4],'C': [1, 10, 100, 1000]}, #svc
    {'kernel': ['linear'], 'C': [0.025, 0.25, 1, 10, 100, 1000]}, #linear kernel svc
    {"max_depth": [4,5,6,7,8],"splitter":["best", "random"]}, #decision tree
    {"max_depth":[4,5,6,7,8], "n_estimators":[10,20], "max_features":[1,2,5]}, #Random forest
]

names_reg = [ "Nearest Neighbors Regressor", "Linear SVR Regressor", "RBF SVR",
         "Decision Tree Regressor", "Random Forest Regressor"]# "Neural Net Regressor",  "Gaussian Process Regressor", "AdaBoost Regressor"]


regressors = [
    KNeighborsRegressor(5),   
    SVR(),
    SVR(),
    DecisionTreeRegressor(),
    RandomForestRegressor()
#     MLPRegressor(alpha=1, max_iter=1000),
#     GaussianProcessRegressor(1.0 * RBF(1.0)),
#     AdaBoostRegressor(),
    
]

params_regressors = [
    {"n_neighbors":[3,4,5], "algorithm" :["auto", "ball_tree", "kd_tree", "brute"]},
    {'kernel': ['rbf'], 'gamma': [1,1e-1, 1e-2, 1e-3, 1e-4],'C': [1, 10, 100, 1000]}, #svc
    {'kernel': ['linear'], 'C': [0.025, 0.25, 1, 10, 100, 1000]}, #linear kernel svc
    {"max_depth": [4,5,6,7,8],"splitter":["best", "random"]}, #decision tree
    {"max_depth":[4,5,6,7,8], "n_estimators":[10,20], "max_features":[1,2,5]}, #Random forest
]
# classifiers = classifiers + regressors

# %%
class Trainer:
    
    def __init__(self, df):
        
        self.X = df[['NUMBER_OF_HITS', 'HIT_INTENSITY', 'NUMBER_OF_TUG',
                  'TOTAL_FRAMES_IN_TUG', 'TIME','NUMBER_OF_JERK_FRAMES', 'NUMBER_OF_RINGDROP',
                   'VARIANCE', 'ARC_LENGTH', 'CURVATURE_MAX_COUNT']]
        self.data = df.copy() 
        
    def upsample_data(self, X_train, y_train, p):
        #print("X_train")
            #print(X_train)
            #print("y_train")
            #print(y_train)
            data_Y = pd.DataFrame(y_train)
            data_XY = X_train.join(data_Y)
            df = data_Y.drop_duplicates(subset=[p])
            classes_unique = df.values
            XY_new = pd.DataFrame({'A' : []})
            df1 = data_Y.loc[:,~data_Y.columns.duplicated()]
            max_len = max(df1[p].value_counts())
#             classes_unique = list(data_Y.unique())
#             XY_new = pd.DataFrame({'A' : []})
#             max_len = max(y_train.value_counts())

# suppose actual
# 3 :5
# 4 : 22
# 2 : 10
# 1 : 1
            for i in classes_unique:
                Extracted_X = data_XY[data_XY.loc[:,p].values == i]
                length = len(Extracted_X)
                if length == max_len:
                    Extracted_X_max = pd.DataFrame(Extracted_X)
                    if (XY_new.empty):
                        XY_new = Extracted_X_max.copy()
                        print(i)
                    else:
                        XY_new = pd.concat([XY_new, Extracted_X_max]) #length_XY = len(Extracted_X_max)
                else:
                    Extracted_X_upsampled = resample(Extracted_X, 
                                                   replace=True,     # sample with replacement
                                                   n_samples=max_len,    # to match majority class
                                                   random_state=123) # reproducible results
                    if (XY_new.empty):
                        XY_new = Extracted_X_upsampled.copy()
                    else:
                        XY_new = pd.concat([XY_new, Extracted_X_upsampled])
            return XY_new

    def run(self, classifiers,params, names, prediction_label = None, method = "classify", split_size = 0.20, k_folds = 5,digitize = False, upsample = False):
        
        results = []
        #"select feature type for y label"
        assert prediction_label is not None and prediction_label in self.data.columns

        Y = self.data[[prediction_label]]

        if  prediction_label == "Overall" and digitize: #for overall scores
            Y = np.digitize(np.array(Y),np.array([5.0, 10.0, 15.0, 20.0]))
        
        X_train, X_test, y_train, y_test = train_test_split(self.X, Y, test_size=split_size, random_state= 0)
        
        #print(classes_unique)
        XY_new = pd.DataFrame({'A' : []})
        # Do upsampling if upsample = True 
        if upsample == True:
            XY_new = self.upsample_data(X_train, y_train, p)
             #random.randint(0, 500)) #70 | 30
        if(XY_new.empty):
            X_train = X_train.copy()
            y_train = y_train
        else:  
            X_train = XY_new.iloc[:, :10]
            y_train = XY_new.iloc[:, 10:]
        
        gt_y_test = y_test[[prediction_label]].values.ravel()

        for parameters, model in zip(params, classifiers):
                print(prediction_label,model)
                if method == "classify":
                    clf = GridSearchCV(model, parameters, scoring="accuracy",cv=k_folds)#make_scorer(label_ranking_loss)
                    clf.fit(X_train, y_train.values.ravel())
                    scores = cross_val_score(clf.best_estimator_,X_train, y_train, cv=k_folds)
                    res = {}
                    y_pred = clf.predict(X_test) #y_pred
                    
                    res["estimator_type"] = model.__class__.__name__
                    res["accuracy_test"] = accuracy_score(gt_y_test, y_pred)
                    target_names = ["bad","fair","good","excellent"]
                    print(classification_report(gt_y_test,y_pred))
                    
                    test = cross_val_predict(clf.best_estimator_, self.X, Y.values.ravel(), cv=k_folds)
                    r = pearsonr(test, Y.values.ravel())
#                      print(list(zip(y_pred, gt_y_test)))
#                     r = pearsonr(y_pred, gt_y_test)
                    res["correlation coefficient"] = r[0]
                    res["accuracy_cross_val"] = clf.best_score_
                    res["estimator"] = clf.best_estimator_
                    res["parameter_search_dict"] = clf.best_params_
                    
                    results.append(res)

                    
                elif method == "regression":
                    clf = GridSearchCV(model, parameters,scoring=make_scorer(mean_squared_error), cv=k_folds)
                    clf.fit(X_train, y_train.values.ravel())
#                     scores = cross_val_score(clf,X_train, y_train, cv=k_folds)
                    res = {}
                    y_pred = clf.predict(X_test) #y_pred
#                     y_pred = [round(x) for x in y_pred] #rounding to nearest integer
                    mse = mean_squared_error(y_pred,gt_y_test) #ypred vs gt y for test data
                    
                    test = cross_val_predict(clf.best_estimator_, self.X, Y.values.ravel(), cv=k_folds)
                    test = [round(x) for x in test] #rounding to nearest integer
                    r = pearsonr(test, Y.values.ravel())
#                     print(y_pred, gt_y_test)
                    r = pearsonr(y_pred, gt_y_test)
                    res["correlation coeff."] = r[0]
                    res["estimator_type"]= model.__class__.__name__
                    res["mse_test"] = mse
                    res["mse_cross_val"] = clf.best_score_
                    res["estimator"] = clf.best_estimator_
                    res["parameter_search_dict"] = clf.best_params_

                    results.append(res)
                    
                    
        return results

# %%
trainer = Trainer(JOINT)

# %%
preds = ['Hand-eye Coordination', 'Instrument-Tissue Manipulation', 'Dexterity','Flow of procedure', 'Overall']#'Effectualness'

# %%
classifiers
# Out:
# [KNeighborsClassifier(),
#  SVC(),
#  SVC(),
#  DecisionTreeClassifier(),
#  RandomForestClassifier()]

# %%
regressors
# Out:
# [KNeighborsRegressor(),
#  SVR(),
#  SVR(),
#  DecisionTreeRegressor(),
#  RandomForestRegressor()]

# %%
# Without upsampling
res_classifier = {}
for p in preds:
    res_classifier[p]=trainer.run(classifiers,params_classifiers, names, p,split_size = 0.3)
# Out:
# Hand-eye Coordination KNeighborsClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         2
#            3       0.43      0.23      0.30        13
#            4       0.55      0.85      0.67        13
#
#     accuracy                           0.50        28
#    macro avg       0.24      0.27      0.24        28
# weighted avg       0.45      0.50      0.45        28
#
# Hand-eye Coordination SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         2
#            3       0.57      0.31      0.40        13
#            4       0.55      0.85      0.67        13
#
#     accuracy                           0.54        28
#    macro avg       0.28      0.29      0.27        28
# weighted avg       0.52      0.54      0.50        28
#
# Hand-eye Coordination SVC()
#               precision    recall  f1-score   support
#
#            2       0.50      0.50      0.50         2
#            3       0.75      0.46      0.57        13
#            4       0.67      0.92      0.77        13
#
#     accuracy                           0.68        28
#    macro avg       0.64      0.63      0.62        28
# weighted avg       0.69      0.68      0.66        28
#
# Hand-eye Coordination DecisionTreeClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.50      0.50      0.50         2
#            3       0.50      0.23      0.32        13
#            4       0.53      0.77      0.62        13
#
#     accuracy                           0.50        28
#    macro avg       0.38      0.38      0.36        28
# weighted avg       0.51      0.50      0.47        28
#
# Hand-eye Coordination RandomForestClassifier()
#               precision    recall  f1-score   support
#
#            2       0.50      0.50      0.50         2
#            3       0.33      0.31      0.32        13
#            4       0.43      0.46      0.44        13
#
#     accuracy                           0.39        28
#    macro avg       0.42      0.42      0.42        28
# weighted avg       0.39      0.39      0.39        28
#
# Instrument-Tissue Manipulation KNeighborsClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         5
#            3       0.50      0.67      0.57        15
#            4       0.50      0.38      0.43         8
#
#     accuracy                           0.46        28
#    macro avg       0.25      0.26      0.25        28
# weighted avg       0.41      0.46      0.43        28
#
# Instrument-Tissue Manipulation SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         5
#            3       0.53      0.53      0.53        15
#            4       0.50      0.62      0.56         8
#
#     accuracy                           0.46        28
#    macro avg       0.26      0.29      0.27        28
# weighted avg       0.43      0.46      0.44        28
#
# Instrument-Tissue Manipulation SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/scipy/stats/stats.py:3010: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         5
#            3       0.54      1.00      0.70        15
#            4       0.00      0.00      0.00         8
#
#     accuracy                           0.54        28
#    macro avg       0.18      0.33      0.23        28
# weighted avg       0.29      0.54      0.37        28
#
# Instrument-Tissue Manipulation DecisionTreeClassifier()
#               precision    recall  f1-score   support
#
#            2       1.00      0.20      0.33         5
#            3       0.63      0.80      0.71        15
#            4       0.62      0.62      0.62         8
#
#     accuracy                           0.64        28
#    macro avg       0.75      0.54      0.55        28
# weighted avg       0.70      0.64      0.62        28
#
# Instrument-Tissue Manipulation RandomForestClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 3 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            2       0.33      0.20      0.25         5
#            3       0.50      0.53      0.52        15
#            4       0.44      0.50      0.47         8
#
#     accuracy                           0.46        28
#    macro avg       0.43      0.41      0.41        28
# weighted avg       0.45      0.46      0.46        28
#
# Dexterity KNeighborsClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            2       0.50      0.50      0.50         2
#            3       0.71      0.50      0.59        10
#            4       0.74      0.88      0.80        16
#
#     accuracy                           0.71        28
#    macro avg       0.65      0.62      0.63        28
# weighted avg       0.71      0.71      0.70        28
#
# Dexterity SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         2
#            3       0.60      0.30      0.40        10
#            4       0.61      0.88      0.72        16
#
#     accuracy                           0.61        28
#    macro avg       0.40      0.39      0.37        28
# weighted avg       0.56      0.61      0.55        28
#
# Dexterity SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         2
#            3       0.60      0.30      0.40        10
#            4       0.61      0.88      0.72        16
#
#     accuracy                           0.61        28
#    macro avg       0.40      0.39      0.37        28
# weighted avg       0.56      0.61      0.55        28
#
# Dexterity DecisionTreeClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         2
#            3       0.60      0.60      0.60        10
#            4       0.76      0.81      0.79        16
#
#     accuracy                           0.68        28
#    macro avg       0.34      0.35      0.35        28
# weighted avg       0.65      0.68      0.66        28
#
# Dexterity RandomForestClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         2
#            3       0.56      0.50      0.53        10
#            4       0.68      0.81      0.74        16
#
#     accuracy                           0.64        28
#    macro avg       0.41      0.44      0.42        28
# weighted avg       0.59      0.64      0.61        28
#
# Flow of procedure KNeighborsClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         6
#            4       0.81      0.95      0.88        22
#
#     accuracy                           0.75        28
#    macro avg       0.27      0.32      0.29        28
# weighted avg       0.63      0.75      0.69        28
#
# Flow of procedure SVC()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         6
#            4       0.78      0.95      0.86        22
#
#     accuracy                           0.75        28
#    macro avg       0.39      0.48      0.43        28
# weighted avg       0.61      0.75      0.67        28
#
# Flow of procedure SVC()
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         6
#            4       0.78      0.95      0.86        22
#
#     accuracy                           0.75        28
#    macro avg       0.39      0.48      0.43        28
# weighted avg       0.61      0.75      0.67        28
#
# Flow of procedure DecisionTreeClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            3       0.40      0.33      0.36         6
#            4       0.83      0.86      0.84        22
#
#     accuracy                           0.75        28
#    macro avg       0.61      0.60      0.60        28
# weighted avg       0.73      0.75      0.74        28
#
# Flow of procedure RandomForestClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         6
#            4       0.78      0.95      0.86        22
#
#     accuracy                           0.75        28
#    macro avg       0.39      0.48      0.43        28
# weighted avg       0.61      0.75      0.67        28
#
# Overall KNeighborsClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            7       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         1
#           11       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         2
#           16       0.00      0.00      0.00         1
#           17       0.25      0.11      0.15         9
#           18       0.00      0.00      0.00         5
#           19       0.00      0.00      0.00         4
#           20       0.20      0.33      0.25         3
#
#     accuracy                           0.07        28
#    macro avg       0.04      0.04      0.04        28
# weighted avg       0.10      0.07      0.08        28
#
# Overall SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#           10       0.50      1.00      0.67         1
#           11       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         2
#           16       0.00      0.00      0.00         1
#           17       0.00      0.00      0.00         9
#           18       0.00      0.00      0.00         5
#           19       0.00      0.00      0.00         4
#           20       0.20      0.33      0.25         3
#
#     accuracy                           0.07        28
#    macro avg       0.08      0.15      0.10        28
# weighted avg       0.04      0.07      0.05        28
#
# Overall SVC()
#               precision    recall  f1-score   support
#
#           10       0.50      1.00      0.67         1
#           11       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         2
#           16       0.00      0.00      0.00         1
#           17       0.00      0.00      0.00         9
#           18       0.00      0.00      0.00         5
#           19       0.00      0.00      0.00         4
#           20       0.17      0.33      0.22         3
#
#     accuracy                           0.07        28
#    macro avg       0.07      0.15      0.10        28
# weighted avg       0.04      0.07      0.05        28
#
# Overall DecisionTreeClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/model_selection/_split.py:672: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   % (min_groups, self.n_splits)), UserWarning)
#               precision    recall  f1-score   support
#
#            7       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         1
#           11       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         2
#           16       0.00      0.00      0.00         1
#           17       0.17      0.11      0.13         9
#           18       0.00      0.00      0.00         5
#           19       0.00      0.00      0.00         4
#           20       0.43      1.00      0.60         3
#
#     accuracy                           0.14        28
#    macro avg       0.06      0.11      0.07        28
# weighted avg       0.10      0.14      0.11        28
#
# Overall RandomForestClassifier()
#               precision    recall  f1-score   support
#
#           10       1.00      1.00      1.00         1
#           11       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         2
#           16       0.00      0.00      0.00         1
#           17       0.20      0.11      0.14         9
#           18       0.00      0.00      0.00         5
#           19       0.00      0.00      0.00         4
#           20       0.38      1.00      0.55         3
#
#     accuracy                           0.18        28
#    macro avg       0.17      0.23      0.19        28
# weighted avg       0.14      0.18      0.14        28
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
res_classifier
# Out:
# {'Hand-eye Coordination': [{'estimator_type': 'KNeighborsClassifier',
#    'accuracy_test': 0.5,
#    'correlation coefficient': 0.34101027820468,
#    'accuracy_cross_val': 0.5692307692307692,
#    'estimator': KNeighborsClassifier(),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 5}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.5357142857142857,
#    'correlation coefficient': 0.25420766193439776,
#    'accuracy_cross_val': 0.6,
#    'estimator': SVC(C=1, gamma=0.1),
#    'parameter_search_dict': {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.6785714285714286,
#    'correlation coefficient': 0.6235703592690933,
#    'accuracy_cross_val': 0.5538461538461539,
#    'estimator': SVC(C=1, kernel='linear'),
#    'parameter_search_dict': {'C': 1, 'kernel': 'linear'}},
#   {'estimator_type': 'DecisionTreeClassifier',
#    'accuracy_test': 0.5,
#    'correlation coefficient': 0.3051514524082798,
#    'accuracy_cross_val': 0.6,
#    'estimator': DecisionTreeClassifier(max_depth=7, splitter='random'),
#    'parameter_search_dict': {'max_depth': 7, 'splitter': 'random'}},
#   {'estimator_type': 'RandomForestClassifier',
#    'accuracy_test': 0.39285714285714285,
#    'correlation coefficient': 0.21227927124054244,
#    'accuracy_cross_val': 0.6923076923076923,
#    'estimator': RandomForestClassifier(max_depth=5, max_features=5, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 5,
#     'max_features': 5,
#     'n_estimators': 20}}],
#  'Instrument-Tissue Manipulation': [{'estimator_type': 'KNeighborsClassifier',
#    'accuracy_test': 0.4642857142857143,
#    'correlation coefficient': 0.2302032722696681,
#    'accuracy_cross_val': 0.5384615384615384,
#    'estimator': KNeighborsClassifier(n_neighbors=4),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 4}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.4642857142857143,
#    'correlation coefficient': 0.42663886830575815,
#    'accuracy_cross_val': 0.5692307692307692,
#    'estimator': SVC(C=1000, gamma=0.01),
#    'parameter_search_dict': {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.5357142857142857,
#    'correlation coefficient': nan,
#    'accuracy_cross_val': 0.5384615384615384,
#    'estimator': SVC(C=0.025, kernel='linear'),
#    'parameter_search_dict': {'C': 0.025, 'kernel': 'linear'}},
#   {'estimator_type': 'DecisionTreeClassifier',
#    'accuracy_test': 0.6428571428571429,
#    'correlation coefficient': 0.5475895344169858,
#    'accuracy_cross_val': 0.5384615384615384,
#    'estimator': DecisionTreeClassifier(max_depth=5),
#    'parameter_search_dict': {'max_depth': 5, 'splitter': 'best'}},
#   {'estimator_type': 'RandomForestClassifier',
#    'accuracy_test': 0.4642857142857143,
#    'correlation coefficient': 0.3738393619518963,
#    'accuracy_cross_val': 0.6,
#    'estimator': RandomForestClassifier(max_depth=5, max_features=5, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 5,
#     'max_features': 5,
#     'n_estimators': 20}}],
#  'Dexterity': [{'estimator_type': 'KNeighborsClassifier',
#    'accuracy_test': 0.7142857142857143,
#    'correlation coefficient': 0.5074692932700856,
#    'accuracy_cross_val': 0.5846153846153846,
#    'estimator': KNeighborsClassifier(n_neighbors=4),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 4}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.6071428571428571,
#    'correlation coefficient': 0.07438814984891522,
#    'accuracy_cross_val': 0.6615384615384615,
#    'estimator': SVC(C=1, gamma=0.01),
#    'parameter_search_dict': {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.6071428571428571,
#    'correlation coefficient': 0.07438814984891522,
#    'accuracy_cross_val': 0.6461538461538462,
#    'estimator': SVC(C=0.025, kernel='linear'),
#    'parameter_search_dict': {'C': 0.025, 'kernel': 'linear'}},
#   {'estimator_type': 'DecisionTreeClassifier',
#    'accuracy_test': 0.6785714285714286,
#    'correlation coefficient': 0.6280447997343249,
#    'accuracy_cross_val': 0.5846153846153846,
#    'estimator': DecisionTreeClassifier(max_depth=7, splitter='random'),
#    'parameter_search_dict': {'max_depth': 7, 'splitter': 'random'}},
#   {'estimator_type': 'RandomForestClassifier',
#    'accuracy_test': 0.6428571428571429,
#    'correlation coefficient': 0.30501740827600116,
#    'accuracy_cross_val': 0.676923076923077,
#    'estimator': RandomForestClassifier(max_depth=5, max_features=5, n_estimators=10),
#    'parameter_search_dict': {'max_depth': 5,
#     'max_features': 5,
#     'n_estimators': 10}}],
#  'Flow of procedure': [{'estimator_type': 'KNeighborsClassifier',
#    'accuracy_test': 0.75,
#    'correlation coefficient': 0.28897547294682174,
#    'accuracy_cross_val': 0.8307692307692308,
#    'estimator': KNeighborsClassifier(n_neighbors=4),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 4}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.75,
#    'correlation coefficient': -0.10050378152592118,
#    'accuracy_cross_val': 0.8153846153846154,
#    'estimator': SVC(C=10, gamma=0.01),
#    'parameter_search_dict': {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.75,
#    'correlation coefficient': -0.10050378152592118,
#    'accuracy_cross_val': 0.8153846153846154,
#    'estimator': SVC(C=0.25, kernel='linear'),
#    'parameter_search_dict': {'C': 0.25, 'kernel': 'linear'}},
#   {'estimator_type': 'DecisionTreeClassifier',
#    'accuracy_test': 0.75,
#    'correlation coefficient': 0.2110267265416586,
#    'accuracy_cross_val': 0.7846153846153846,
#    'estimator': DecisionTreeClassifier(max_depth=5, splitter='random'),
#    'parameter_search_dict': {'max_depth': 5, 'splitter': 'random'}},
#   {'estimator_type': 'RandomForestClassifier',
#    'accuracy_test': 0.75,
#    'correlation coefficient': -0.10050378152592118,
#    'accuracy_cross_val': 0.8461538461538461,
#    'estimator': RandomForestClassifier(max_depth=4, max_features=2, n_estimators=10),
#    'parameter_search_dict': {'max_depth': 4,
#     'max_features': 2,
#     'n_estimators': 10}}],
#  'Overall': [{'estimator_type': 'KNeighborsClassifier',
#    'accuracy_test': 0.07142857142857142,
#    'correlation coefficient': 0.39522142915840125,
#    'accuracy_cross_val': 0.23076923076923075,
#    'estimator': KNeighborsClassifier(),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 5}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.07142857142857142,
#    'correlation coefficient': 0.581675744857187,
#    'accuracy_cross_val': 0.27692307692307694,
#    'estimator': SVC(C=100, gamma=0.001),
#    'parameter_search_dict': {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.07142857142857142,
#    'correlation coefficient': 0.5769747362693864,
#    'accuracy_cross_val': 0.27692307692307694,
#    'estimator': SVC(C=0.25, kernel='linear'),
#    'parameter_search_dict': {'C': 0.25, 'kernel': 'linear'}},
#   {'estimator_type': 'DecisionTreeClassifier',
#    'accuracy_test': 0.14285714285714285,
#    'correlation coefficient': 0.5038557632288819,
#    'accuracy_cross_val': 0.21538461538461542,
#    'estimator': DecisionTreeClassifier(max_depth=8, splitter='random'),
#    'parameter_search_dict': {'max_depth': 8, 'splitter': 'random'}},
#   {'estimator_type': 'RandomForestClassifier',
#    'accuracy_test': 0.17857142857142858,
#    'correlation coefficient': 0.4630313164439813,
#    'accuracy_cross_val': 0.2923076923076923,
#    'estimator': RandomForestClassifier(max_depth=4, max_features=2, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 4,
#     'max_features': 2,
#     'n_estimators': 20}}]}

# %%
result = {}
for key, val in res_classifier.items():
    df = pd.DataFrame(val)
    df["Metric"] = key
    result[key]= df

# %%
data = pd.concat(result)

# %%
data
# Out:
#                                   accuracy_cross_val  accuracy_test  \
# Dexterity                      0            0.584615       0.714286
#                                1            0.661538       0.607143
#                                2            0.646154       0.607143
#                                3            0.584615       0.678571
#                                4            0.676923       0.642857
# Flow of procedure              0            0.830769       0.750000
#                                1            0.815385       0.750000
#                                2            0.815385       0.750000
#                                3            0.784615       0.750000
#                                4            0.846154       0.750000
# Hand-eye Coordination          0            0.569231       0.500000
#                                1            0.600000       0.535714
#                                2            0.553846       0.678571
#                                3            0.600000       0.500000
#                                4            0.692308       0.392857
# Instrument-Tissue Manipulation 0            0.538462       0.464286
#                                1            0.569231       0.464286
#                                2            0.538462       0.535714
#                                3            0.538462       0.642857
#                                4            0.600000       0.464286
# Overall                        0            0.230769       0.071429
#                                1            0.276923       0.071429
#                                2            0.276923       0.071429
#                                3            0.215385       0.142857
#                                4            0.292308       0.178571
#
#                                   correlation coefficient  \
# Dexterity                      0                 0.507469
#                                1                 0.074388
#                                2                 0.074388
#                                3                 0.628045
#                                4                 0.305017
# Flow of procedure              0                 0.288975
#                                1                -0.100504
#                                2                -0.100504
#                                3                 0.211027
#                                4                -0.100504
# Hand-eye Coordination          0                 0.341010
#                                1                 0.254208
#                                2                 0.623570
#                                3                 0.305151
#                                4                 0.212279
# Instrument-Tissue Manipulation 0                 0.230203
#                                1                 0.426639
#                                2                      NaN
#                                3                 0.547590
#                                4                 0.373839
# Overall                        0                 0.395221
#                                1                 0.581676
#                                2                 0.576975
#                                3                 0.503856
#                                4                 0.463031
#
#                                                                           estimator  \
# Dexterity                      0                KNeighborsClassifier(n_neighbors=4)
#                                1                               SVC(C=1, gamma=0.01)
#                                2                      SVC(C=0.025, kernel='linear')
#                                3  DecisionTreeClassifier(max_depth=7, splitter='...
#                                4  (DecisionTreeClassifier(max_depth=5, max_featu...
# Flow of procedure              0                KNeighborsClassifier(n_neighbors=4)
#                                1                              SVC(C=10, gamma=0.01)
#                                2                       SVC(C=0.25, kernel='linear')
#                                3  DecisionTreeClassifier(max_depth=5, splitter='...
#                                4  (DecisionTreeClassifier(max_depth=4, max_featu...
# Hand-eye Coordination          0                             KNeighborsClassifier()
#                                1                                SVC(C=1, gamma=0.1)
#                                2                          SVC(C=1, kernel='linear')
#                                3  DecisionTreeClassifier(max_depth=7, splitter='...
#                                4  (DecisionTreeClassifier(max_depth=5, max_featu...
# Instrument-Tissue Manipulation 0                KNeighborsClassifier(n_neighbors=4)
#                                1                            SVC(C=1000, gamma=0.01)
#                                2                      SVC(C=0.025, kernel='linear')
#                                3                DecisionTreeClassifier(max_depth=5)
#                                4  (DecisionTreeClassifier(max_depth=5, max_featu...
# Overall                        0                             KNeighborsClassifier()
#                                1                            SVC(C=100, gamma=0.001)
#                                2                       SVC(C=0.25, kernel='linear')
#                                3  DecisionTreeClassifier(max_depth=8, splitter='...
#                                4  (DecisionTreeClassifier(max_depth=4, max_featu...
#
#                                           estimator_type  \
# Dexterity                      0    KNeighborsClassifier
#                                1                     SVC
#                                2                     SVC
#                                3  DecisionTreeClassifier
#                                4  RandomForestClassifier
# Flow of procedure              0    KNeighborsClassifier
#                                1                     SVC
#                                2                     SVC
#                                3  DecisionTreeClassifier
#                                4  RandomForestClassifier
# Hand-eye Coordination          0    KNeighborsClassifier
#                                1                     SVC
#                                2                     SVC
#                                3  DecisionTreeClassifier
#                                4  RandomForestClassifier
# Instrument-Tissue Manipulation 0    KNeighborsClassifier
#                                1                     SVC
#                                2                     SVC
#                                3  DecisionTreeClassifier
#                                4  RandomForestClassifier
# Overall                        0    KNeighborsClassifier
#                                1                     SVC
#                                2                     SVC
#                                3  DecisionTreeClassifier
#                                4  RandomForestClassifier
#
#                                                               parameter_search_dict  \
# Dexterity                      0            {'algorithm': 'auto', 'n_neighbors': 4}
#                                1           {'C': 1, 'gamma': 0.01, 'kernel': 'rbf'}
#                                2                   {'C': 0.025, 'kernel': 'linear'}
#                                3             {'max_depth': 7, 'splitter': 'random'}
#                                4  {'max_depth': 5, 'max_features': 5, 'n_estimat...
# Flow of procedure              0            {'algorithm': 'auto', 'n_neighbors': 4}
#                                1          {'C': 10, 'gamma': 0.01, 'kernel': 'rbf'}
#                                2                    {'C': 0.25, 'kernel': 'linear'}
#                                3             {'max_depth': 5, 'splitter': 'random'}
#                                4  {'max_depth': 4, 'max_features': 2, 'n_estimat...
# Hand-eye Coordination          0            {'algorithm': 'auto', 'n_neighbors': 5}
#                                1            {'C': 1, 'gamma': 0.1, 'kernel': 'rbf'}
#                                2                       {'C': 1, 'kernel': 'linear'}
#                                3             {'max_depth': 7, 'splitter': 'random'}
#                                4  {'max_depth': 5, 'max_features': 5, 'n_estimat...
# Instrument-Tissue Manipulation 0            {'algorithm': 'auto', 'n_neighbors': 4}
#                                1        {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
#                                2                   {'C': 0.025, 'kernel': 'linear'}
#                                3               {'max_depth': 5, 'splitter': 'best'}
#                                4  {'max_depth': 5, 'max_features': 5, 'n_estimat...
# Overall                        0            {'algorithm': 'auto', 'n_neighbors': 5}
#                                1        {'C': 100, 'gamma': 0.001, 'kernel': 'rbf'}
#                                2                    {'C': 0.25, 'kernel': 'linear'}
#                                3             {'max_depth': 8, 'splitter': 'random'}
#                                4  {'max_depth': 4, 'max_features': 2, 'n_estimat...
#
#                                                           Metric
# Dexterity                      0                       Dexterity
#                                1                       Dexterity
#                                2                       Dexterity
#                                3                       Dexterity
#                                4                       Dexterity
# Flow of procedure              0               Flow of procedure
#                                1               Flow of procedure
#                                2               Flow of procedure
#                                3               Flow of procedure
#                                4               Flow of procedure
# Hand-eye Coordination          0           Hand-eye Coordination
#                                1           Hand-eye Coordination
#                                2           Hand-eye Coordination
#                                3           Hand-eye Coordination
#                                4           Hand-eye Coordination
# Instrument-Tissue Manipulation 0  Instrument-Tissue Manipulation
#                                1  Instrument-Tissue Manipulation
#                                2  Instrument-Tissue Manipulation
#                                3  Instrument-Tissue Manipulation
#                                4  Instrument-Tissue Manipulation
# Overall                        0                         Overall
#                                1                         Overall
#                                2                         Overall
#                                3                         Overall
#                                4                         Overall

# %%
data.to_csv("./data_without_Upsampling_1.csv")

# %%
#With upsampling
res_classifier_up = {}
for p in preds:
    res_classifier_up[p]=trainer.run(classifiers,params_classifiers, names, p, upsample = True, split_size= 0.3)
# Out:
# Hand-eye Coordination KNeighborsClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         2
#            3       0.56      0.38      0.45        13
#            4       0.59      0.77      0.67        13
#
#     accuracy                           0.54        28
#    macro avg       0.29      0.29      0.28        28
# weighted avg       0.53      0.54      0.52        28
#
# Hand-eye Coordination SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         2
#            3       0.50      0.08      0.13        13
#            4       0.50      1.00      0.67        13
#
#     accuracy                           0.50        28
#    macro avg       0.33      0.36      0.27        28
# weighted avg       0.46      0.50      0.37        28
#
# Hand-eye Coordination SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       1.00      0.50      0.67         2
#            3       0.40      0.15      0.22        13
#            4       0.56      0.77      0.65        13
#
#     accuracy                           0.46        28
#    macro avg       0.49      0.36      0.38        28
# weighted avg       0.52      0.46      0.45        28
#
# Hand-eye Coordination DecisionTreeClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.50      0.50      0.50         2
#            3       0.39      0.54      0.45        13
#            4       0.33      0.15      0.21        13
#
#     accuracy                           0.36        28
#    macro avg       0.31      0.30      0.29        28
# weighted avg       0.37      0.36      0.34        28
#
# Hand-eye Coordination RandomForestClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.50      0.50      0.50         2
#            3       0.50      0.46      0.48        13
#            4       0.62      0.62      0.62        13
#
#     accuracy                           0.54        28
#    macro avg       0.40      0.39      0.40        28
# weighted avg       0.55      0.54      0.54        28
#
# Instrument-Tissue Manipulation KNeighborsClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         5
#            3       0.50      0.33      0.40        15
#            4       0.33      0.62      0.43         8
#
#     accuracy                           0.36        28
#    macro avg       0.21      0.24      0.21        28
# weighted avg       0.36      0.36      0.34        28
#
# Instrument-Tissue Manipulation SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         5
#            3       0.52      0.80      0.63        15
#            4       0.40      0.25      0.31         8
#
#     accuracy                           0.50        28
#    macro avg       0.31      0.35      0.31        28
# weighted avg       0.39      0.50      0.43        28
#
# Instrument-Tissue Manipulation SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         5
#            3       0.67      0.53      0.59        15
#            4       0.54      0.88      0.67         8
#
#     accuracy                           0.54        28
#    macro avg       0.30      0.35      0.31        28
# weighted avg       0.51      0.54      0.51        28
#
# Instrument-Tissue Manipulation DecisionTreeClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         5
#            3       0.62      0.53      0.57        15
#            4       0.43      0.75      0.55         8
#
#     accuracy                           0.50        28
#    macro avg       0.26      0.32      0.28        28
# weighted avg       0.45      0.50      0.46        28
#
# Instrument-Tissue Manipulation RandomForestClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       1.00      0.20      0.33         5
#            3       0.56      0.60      0.58        15
#            4       0.40      0.50      0.44         8
#
#     accuracy                           0.50        28
#    macro avg       0.49      0.33      0.34        28
# weighted avg       0.59      0.50      0.50        28
#
# Dexterity KNeighborsClassifier()
#               precision    recall  f1-score   support
#
#            2       1.00      0.50      0.67         2
#            3       0.47      0.70      0.56        10
#            4       0.75      0.56      0.64        16
#
#     accuracy                           0.61        28
#    macro avg       0.74      0.59      0.62        28
# weighted avg       0.67      0.61      0.61        28
#
# Dexterity SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         2
#            3       0.50      0.10      0.17        10
#            4       0.58      0.94      0.71        16
#
#     accuracy                           0.57        28
#    macro avg       0.36      0.35      0.29        28
# weighted avg       0.51      0.57      0.47        28
#
# Dexterity SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         2
#            3       0.83      0.50      0.62        10
#            4       0.74      0.88      0.80        16
#
#     accuracy                           0.68        28
#    macro avg       0.39      0.34      0.36        28
# weighted avg       0.72      0.68      0.68        28
#
# Dexterity DecisionTreeClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         2
#            3       0.45      0.50      0.48        10
#            4       0.67      0.62      0.65        16
#
#     accuracy                           0.54        28
#    macro avg       0.28      0.28      0.28        28
# weighted avg       0.54      0.54      0.54        28
#
# Dexterity RandomForestClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         2
#            3       0.58      0.70      0.64        10
#            4       0.87      0.81      0.84        16
#
#     accuracy                           0.71        28
#    macro avg       0.36      0.38      0.37        28
# weighted avg       0.70      0.71      0.71        28
#
# Flow of procedure KNeighborsClassifier()
#               precision    recall  f1-score   support
#
#            3       0.40      0.33      0.36         6
#            4       0.83      0.86      0.84        22
#
#     accuracy                           0.75        28
#    macro avg       0.61      0.60      0.60        28
# weighted avg       0.73      0.75      0.74        28
#
# Flow of procedure SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/scipy/stats/stats.py:3010: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         6
#            4       0.79      1.00      0.88        22
#
#     accuracy                           0.79        28
#    macro avg       0.39      0.50      0.44        28
# weighted avg       0.62      0.79      0.69        28
#
# Flow of procedure SVC()
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         6
#            4       0.78      0.82      0.80        22
#
#     accuracy                           0.64        28
#    macro avg       0.26      0.27      0.27        28
# weighted avg       0.61      0.64      0.63        28
#
# Flow of procedure DecisionTreeClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            2       0.00      0.00      0.00         0
#            3       0.00      0.00      0.00         6
#            4       0.77      0.91      0.83        22
#
#     accuracy                           0.71        28
#    macro avg       0.26      0.30      0.28        28
# weighted avg       0.60      0.71      0.65        28
#
# Flow of procedure RandomForestClassifier()
#               precision    recall  f1-score   support
#
#            3       0.25      0.17      0.20         6
#            4       0.79      0.86      0.83        22
#
#     accuracy                           0.71        28
#    macro avg       0.52      0.52      0.51        28
# weighted avg       0.68      0.71      0.69        28
#
# Overall KNeighborsClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#           10       1.00      1.00      1.00         1
#           11       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         2
#           16       0.00      0.00      0.00         1
#           17       0.17      0.11      0.13         9
#           18       0.00      0.00      0.00         5
#           19       0.25      0.25      0.25         4
#           20       0.00      0.00      0.00         3
#
#     accuracy                           0.11        28
#    macro avg       0.16      0.15      0.15        28
# weighted avg       0.12      0.11      0.11        28
#
# Overall SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#           10       1.00      1.00      1.00         1
#           11       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         2
#           16       0.00      0.00      0.00         1
#           17       0.17      0.11      0.13         9
#           18       0.00      0.00      0.00         5
#           19       0.00      0.00      0.00         4
#           20       0.75      1.00      0.86         3
#
#     accuracy                           0.18        28
#    macro avg       0.21      0.23      0.22        28
# weighted avg       0.17      0.18      0.17        28
#
# Overall SVC()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            7       0.00      0.00      0.00         0
#           10       1.00      1.00      1.00         1
#           11       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         2
#           16       0.17      1.00      0.29         1
#           17       0.20      0.11      0.14         9
#           18       0.00      0.00      0.00         5
#           19       0.00      0.00      0.00         4
#           20       0.33      0.67      0.44         3
#
#     accuracy                           0.18        28
#    macro avg       0.17      0.28      0.19        28
# weighted avg       0.14      0.18      0.14        28
#
# Overall DecisionTreeClassifier()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#            5       0.00      0.00      0.00         0
#            7       0.00      0.00      0.00         0
#           10       0.00      0.00      0.00         1
#           11       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         2
#           16       0.00      0.00      0.00         1
#           17       0.00      0.00      0.00         9
#           18       0.00      0.00      0.00         5
#           19       0.00      0.00      0.00         4
#           20       0.17      1.00      0.29         3
#
#     accuracy                           0.11        28
#    macro avg       0.02      0.09      0.03        28
# weighted avg       0.02      0.11      0.03        28
#
# Overall RandomForestClassifier()
#               precision    recall  f1-score   support
#
#           10       1.00      1.00      1.00         1
#           11       0.00      0.00      0.00         1
#           13       0.00      0.00      0.00         2
#           15       0.00      0.00      0.00         2
#           16       0.00      0.00      0.00         1
#           17       0.17      0.11      0.13         9
#           18       0.00      0.00      0.00         5
#           19       0.12      0.25      0.17         4
#           20       0.00      0.00      0.00         3
#
#     accuracy                           0.11        28
#    macro avg       0.14      0.15      0.14        28
# weighted avg       0.11      0.11      0.10        28
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
res_classifier_up
# Out:
# {'Hand-eye Coordination': [{'estimator_type': 'KNeighborsClassifier',
#    'accuracy_test': 0.5357142857142857,
#    'correlation coefficient': 0.5135836017067027,
#    'accuracy_cross_val': 0.806,
#    'estimator': KNeighborsClassifier(n_neighbors=3),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 3}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.5,
#    'correlation coefficient': 0.4009892578020669,
#    'accuracy_cross_val': 0.8379999999999999,
#    'estimator': SVC(C=1, gamma=1),
#    'parameter_search_dict': {'C': 1, 'gamma': 1, 'kernel': 'rbf'}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.4642857142857143,
#    'correlation coefficient': 0.5111288959897186,
#    'accuracy_cross_val': 0.8220000000000001,
#    'estimator': SVC(C=100, kernel='linear'),
#    'parameter_search_dict': {'C': 100, 'kernel': 'linear'}},
#   {'estimator_type': 'DecisionTreeClassifier',
#    'accuracy_test': 0.35714285714285715,
#    'correlation coefficient': 0.3825193723644774,
#    'accuracy_cross_val': 0.8226666666666667,
#    'estimator': DecisionTreeClassifier(max_depth=6, splitter='random'),
#    'parameter_search_dict': {'max_depth': 6, 'splitter': 'random'}},
#   {'estimator_type': 'RandomForestClassifier',
#    'accuracy_test': 0.5357142857142857,
#    'correlation coefficient': 0.41664633478760055,
#    'accuracy_cross_val': 0.8619999999999999,
#    'estimator': RandomForestClassifier(max_depth=6, max_features=2, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 6,
#     'max_features': 2,
#     'n_estimators': 20}}],
#  'Instrument-Tissue Manipulation': [{'estimator_type': 'KNeighborsClassifier',
#    'accuracy_test': 0.35714285714285715,
#    'correlation coefficient': 0.2441071466076296,
#    'accuracy_cross_val': 0.7642857142857142,
#    'estimator': KNeighborsClassifier(),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 5}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.5,
#    'correlation coefficient': 0.20291808729901947,
#    'accuracy_cross_val': 0.9357142857142857,
#    'estimator': SVC(C=10, gamma=1),
#    'parameter_search_dict': {'C': 10, 'gamma': 1, 'kernel': 'rbf'}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.5357142857142857,
#    'correlation coefficient': 0.19879202457467166,
#    'accuracy_cross_val': 0.7857142857142858,
#    'estimator': SVC(C=10, kernel='linear'),
#    'parameter_search_dict': {'C': 10, 'kernel': 'linear'}},
#   {'estimator_type': 'DecisionTreeClassifier',
#    'accuracy_test': 0.5,
#    'correlation coefficient': 0.2125926107684946,
#    'accuracy_cross_val': 0.8785714285714287,
#    'estimator': DecisionTreeClassifier(max_depth=8, splitter='random'),
#    'parameter_search_dict': {'max_depth': 8, 'splitter': 'random'}},
#   {'estimator_type': 'RandomForestClassifier',
#    'accuracy_test': 0.5,
#    'correlation coefficient': 0.2507496069786489,
#    'accuracy_cross_val': 0.8928571428571429,
#    'estimator': RandomForestClassifier(max_depth=7, max_features=2, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 7,
#     'max_features': 2,
#     'n_estimators': 20}}],
#  'Dexterity': [{'estimator_type': 'KNeighborsClassifier',
#    'accuracy_test': 0.6071428571428571,
#    'correlation coefficient': 0.46056618647183833,
#    'accuracy_cross_val': 0.8051724137931036,
#    'estimator': KNeighborsClassifier(n_neighbors=3),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 3}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.5714285714285714,
#    'correlation coefficient': 0.0,
#    'accuracy_cross_val': 0.9229064039408866,
#    'estimator': SVC(C=1, gamma=1),
#    'parameter_search_dict': {'C': 1, 'gamma': 1, 'kernel': 'rbf'}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.6785714285714286,
#    'correlation coefficient': 0.39477101697586137,
#    'accuracy_cross_val': 0.8746305418719211,
#    'estimator': SVC(C=10, kernel='linear'),
#    'parameter_search_dict': {'C': 10, 'kernel': 'linear'}},
#   {'estimator_type': 'DecisionTreeClassifier',
#    'accuracy_test': 0.5357142857142857,
#    'correlation coefficient': 0.15644655469368596,
#    'accuracy_cross_val': 0.9305418719211822,
#    'estimator': DecisionTreeClassifier(max_depth=7),
#    'parameter_search_dict': {'max_depth': 7, 'splitter': 'best'}},
#   {'estimator_type': 'RandomForestClassifier',
#    'accuracy_test': 0.7142857142857143,
#    'correlation coefficient': 0.5443054931030816,
#    'accuracy_cross_val': 0.9366995073891626,
#    'estimator': RandomForestClassifier(max_depth=7, max_features=1, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 7,
#     'max_features': 1,
#     'n_estimators': 20}}],
#  'Flow of procedure': [{'estimator_type': 'KNeighborsClassifier',
#    'accuracy_test': 0.75,
#    'correlation coefficient': 0.2110267265416586,
#    'accuracy_cross_val': 0.9349999999999999,
#    'estimator': KNeighborsClassifier(n_neighbors=3),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 3}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.7857142857142857,
#    'correlation coefficient': nan,
#    'accuracy_cross_val': 1.0,
#    'estimator': SVC(C=10, gamma=1),
#    'parameter_search_dict': {'C': 10, 'gamma': 1, 'kernel': 'rbf'}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.6428571428571429,
#    'correlation coefficient': 0.07571661464306055,
#    'accuracy_cross_val': 0.97,
#    'estimator': SVC(C=10, kernel='linear'),
#    'parameter_search_dict': {'C': 10, 'kernel': 'linear'}},
#   {'estimator_type': 'DecisionTreeClassifier',
#    'accuracy_test': 0.7142857142857143,
#    'correlation coefficient': -0.13688311876428394,
#    'accuracy_cross_val': 0.975,
#    'estimator': DecisionTreeClassifier(max_depth=8, splitter='random'),
#    'parameter_search_dict': {'max_depth': 8, 'splitter': 'random'}},
#   {'estimator_type': 'RandomForestClassifier',
#    'accuracy_test': 0.7142857142857143,
#    'correlation coefficient': 0.03553345272593512,
#    'accuracy_cross_val': 0.975,
#    'estimator': RandomForestClassifier(max_depth=7, max_features=1, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 7,
#     'max_features': 1,
#     'n_estimators': 20}}],
#  'Overall': [{'estimator_type': 'KNeighborsClassifier',
#    'accuracy_test': 0.10714285714285714,
#    'correlation coefficient': 0.3370420820374009,
#    'accuracy_cross_val': 0.7570409982174688,
#    'estimator': KNeighborsClassifier(n_neighbors=3),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 3}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.17857142857142858,
#    'correlation coefficient': 0.49446459261431897,
#    'accuracy_cross_val': 0.8996434937611408,
#    'estimator': SVC(C=1000, gamma=0.1),
#    'parameter_search_dict': {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}},
#   {'estimator_type': 'SVC',
#    'accuracy_test': 0.17857142857142858,
#    'correlation coefficient': 0.49116834092058376,
#    'accuracy_cross_val': 0.8757575757575756,
#    'estimator': SVC(C=100, kernel='linear'),
#    'parameter_search_dict': {'C': 100, 'kernel': 'linear'}},
#   {'estimator_type': 'DecisionTreeClassifier',
#    'accuracy_test': 0.10714285714285714,
#    'correlation coefficient': 0.6028853748665448,
#    'accuracy_cross_val': 0.8163992869875223,
#    'estimator': DecisionTreeClassifier(max_depth=8, splitter='random'),
#    'parameter_search_dict': {'max_depth': 8, 'splitter': 'random'}},
#   {'estimator_type': 'RandomForestClassifier',
#    'accuracy_test': 0.10714285714285714,
#    'correlation coefficient': 0.44758918101467365,
#    'accuracy_cross_val': 0.8994652406417112,
#    'estimator': RandomForestClassifier(max_depth=8, max_features=1, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 8,
#     'max_features': 1,
#     'n_estimators': 20}}]}

# %%
result_up = {}
for key, val in res_classifier_up.items():
    df = pd.DataFrame(val)
    df["Metric"] = key
    result_up[key]= df

# %%
data_up = pd.concat(result_up)

# %%
data_up
# Out:
#                                   accuracy_cross_val  accuracy_test  \
# Dexterity                      0            0.805172       0.607143
#                                1            0.922906       0.571429
#                                2            0.874631       0.678571
#                                3            0.930542       0.535714
#                                4            0.936700       0.714286
# Flow of procedure              0            0.935000       0.750000
#                                1            1.000000       0.785714
#                                2            0.970000       0.642857
#                                3            0.975000       0.714286
#                                4            0.975000       0.714286
# Hand-eye Coordination          0            0.806000       0.535714
#                                1            0.838000       0.500000
#                                2            0.822000       0.464286
#                                3            0.822667       0.357143
#                                4            0.862000       0.535714
# Instrument-Tissue Manipulation 0            0.764286       0.357143
#                                1            0.935714       0.500000
#                                2            0.785714       0.535714
#                                3            0.878571       0.500000
#                                4            0.892857       0.500000
# Overall                        0            0.757041       0.107143
#                                1            0.899643       0.178571
#                                2            0.875758       0.178571
#                                3            0.816399       0.107143
#                                4            0.899465       0.107143
#
#                                   correlation coefficient  \
# Dexterity                      0                 0.460566
#                                1                 0.000000
#                                2                 0.394771
#                                3                 0.156447
#                                4                 0.544305
# Flow of procedure              0                 0.211027
#                                1                      NaN
#                                2                 0.075717
#                                3                -0.136883
#                                4                 0.035533
# Hand-eye Coordination          0                 0.513584
#                                1                 0.400989
#                                2                 0.511129
#                                3                 0.382519
#                                4                 0.416646
# Instrument-Tissue Manipulation 0                 0.244107
#                                1                 0.202918
#                                2                 0.198792
#                                3                 0.212593
#                                4                 0.250750
# Overall                        0                 0.337042
#                                1                 0.494465
#                                2                 0.491168
#                                3                 0.602885
#                                4                 0.447589
#
#                                                                           estimator  \
# Dexterity                      0                KNeighborsClassifier(n_neighbors=3)
#                                1                                  SVC(C=1, gamma=1)
#                                2                         SVC(C=10, kernel='linear')
#                                3                DecisionTreeClassifier(max_depth=7)
#                                4  (DecisionTreeClassifier(max_depth=7, max_featu...
# Flow of procedure              0                KNeighborsClassifier(n_neighbors=3)
#                                1                                 SVC(C=10, gamma=1)
#                                2                         SVC(C=10, kernel='linear')
#                                3  DecisionTreeClassifier(max_depth=8, splitter='...
#                                4  (DecisionTreeClassifier(max_depth=7, max_featu...
# Hand-eye Coordination          0                KNeighborsClassifier(n_neighbors=3)
#                                1                                  SVC(C=1, gamma=1)
#                                2                        SVC(C=100, kernel='linear')
#                                3  DecisionTreeClassifier(max_depth=6, splitter='...
#                                4  (DecisionTreeClassifier(max_depth=6, max_featu...
# Instrument-Tissue Manipulation 0                             KNeighborsClassifier()
#                                1                                 SVC(C=10, gamma=1)
#                                2                         SVC(C=10, kernel='linear')
#                                3  DecisionTreeClassifier(max_depth=8, splitter='...
#                                4  (DecisionTreeClassifier(max_depth=7, max_featu...
# Overall                        0                KNeighborsClassifier(n_neighbors=3)
#                                1                             SVC(C=1000, gamma=0.1)
#                                2                        SVC(C=100, kernel='linear')
#                                3  DecisionTreeClassifier(max_depth=8, splitter='...
#                                4  (DecisionTreeClassifier(max_depth=8, max_featu...
#
#                                           estimator_type  \
# Dexterity                      0    KNeighborsClassifier
#                                1                     SVC
#                                2                     SVC
#                                3  DecisionTreeClassifier
#                                4  RandomForestClassifier
# Flow of procedure              0    KNeighborsClassifier
#                                1                     SVC
#                                2                     SVC
#                                3  DecisionTreeClassifier
#                                4  RandomForestClassifier
# Hand-eye Coordination          0    KNeighborsClassifier
#                                1                     SVC
#                                2                     SVC
#                                3  DecisionTreeClassifier
#                                4  RandomForestClassifier
# Instrument-Tissue Manipulation 0    KNeighborsClassifier
#                                1                     SVC
#                                2                     SVC
#                                3  DecisionTreeClassifier
#                                4  RandomForestClassifier
# Overall                        0    KNeighborsClassifier
#                                1                     SVC
#                                2                     SVC
#                                3  DecisionTreeClassifier
#                                4  RandomForestClassifier
#
#                                                               parameter_search_dict  \
# Dexterity                      0            {'algorithm': 'auto', 'n_neighbors': 3}
#                                1              {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
#                                2                      {'C': 10, 'kernel': 'linear'}
#                                3               {'max_depth': 7, 'splitter': 'best'}
#                                4  {'max_depth': 7, 'max_features': 1, 'n_estimat...
# Flow of procedure              0            {'algorithm': 'auto', 'n_neighbors': 3}
#                                1             {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
#                                2                      {'C': 10, 'kernel': 'linear'}
#                                3             {'max_depth': 8, 'splitter': 'random'}
#                                4  {'max_depth': 7, 'max_features': 1, 'n_estimat...
# Hand-eye Coordination          0            {'algorithm': 'auto', 'n_neighbors': 3}
#                                1              {'C': 1, 'gamma': 1, 'kernel': 'rbf'}
#                                2                     {'C': 100, 'kernel': 'linear'}
#                                3             {'max_depth': 6, 'splitter': 'random'}
#                                4  {'max_depth': 6, 'max_features': 2, 'n_estimat...
# Instrument-Tissue Manipulation 0            {'algorithm': 'auto', 'n_neighbors': 5}
#                                1             {'C': 10, 'gamma': 1, 'kernel': 'rbf'}
#                                2                      {'C': 10, 'kernel': 'linear'}
#                                3             {'max_depth': 8, 'splitter': 'random'}
#                                4  {'max_depth': 7, 'max_features': 2, 'n_estimat...
# Overall                        0            {'algorithm': 'auto', 'n_neighbors': 3}
#                                1         {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
#                                2                     {'C': 100, 'kernel': 'linear'}
#                                3             {'max_depth': 8, 'splitter': 'random'}
#                                4  {'max_depth': 8, 'max_features': 1, 'n_estimat...
#
#                                                           Metric
# Dexterity                      0                       Dexterity
#                                1                       Dexterity
#                                2                       Dexterity
#                                3                       Dexterity
#                                4                       Dexterity
# Flow of procedure              0               Flow of procedure
#                                1               Flow of procedure
#                                2               Flow of procedure
#                                3               Flow of procedure
#                                4               Flow of procedure
# Hand-eye Coordination          0           Hand-eye Coordination
#                                1           Hand-eye Coordination
#                                2           Hand-eye Coordination
#                                3           Hand-eye Coordination
#                                4           Hand-eye Coordination
# Instrument-Tissue Manipulation 0  Instrument-Tissue Manipulation
#                                1  Instrument-Tissue Manipulation
#                                2  Instrument-Tissue Manipulation
#                                3  Instrument-Tissue Manipulation
#                                4  Instrument-Tissue Manipulation
# Overall                        0                         Overall
#                                1                         Overall
#                                2                         Overall
#                                3                         Overall
#                                4                         Overall

# %%
data_up.to_csv("./data_with_Upsampling_1.csv")

# %%
res = {}
for p in preds:
    res[p]=trainer.run(regressors,params_regressors, names,p,method="regression")
# Out:
# Hand-eye Coordination KNeighborsRegressor()
# Hand-eye Coordination SVR()
# Hand-eye Coordination SVR()
# Hand-eye Coordination DecisionTreeRegressor()
# Hand-eye Coordination RandomForestRegressor()
# Instrument-Tissue Manipulation KNeighborsRegressor()
# Instrument-Tissue Manipulation SVR()
# Instrument-Tissue Manipulation SVR()
# Instrument-Tissue Manipulation DecisionTreeRegressor()
# Instrument-Tissue Manipulation RandomForestRegressor()
# Dexterity KNeighborsRegressor()
# Dexterity SVR()
# Dexterity SVR()
# Dexterity DecisionTreeRegressor()
# Dexterity RandomForestRegressor()
# Flow of procedure KNeighborsRegressor()
# Flow of procedure SVR()
# Flow of procedure SVR()
# Flow of procedure DecisionTreeRegressor()
# Flow of procedure RandomForestRegressor()
# Overall KNeighborsRegressor()
# Overall SVR()
# Overall SVR()
# Overall DecisionTreeRegressor()
# Overall RandomForestRegressor()

# %%
res
# Out:
# {'Hand-eye Coordination': [{'correlation coeff.': 0.5330663127479722,
#    'estimator_type': 'KNeighborsRegressor',
#    'mse_test': 0.34502923976608185,
#    'mse_cross_val': 0.48772486772486773,
#    'estimator': KNeighborsRegressor(n_neighbors=3),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 3}},
#   {'correlation coeff.': 0.3316858697634714,
#    'estimator_type': 'SVR',
#    'mse_test': 0.620731664403309,
#    'mse_cross_val': 1.081935951257531,
#    'estimator': SVR(C=1000, gamma=0.01),
#    'parameter_search_dict': {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}},
#   {'correlation coeff.': 0.5595642097831907,
#    'estimator_type': 'SVR',
#    'mse_test': 0.324693134165462,
#    'mse_cross_val': 0.4353286467411861,
#    'estimator': SVR(C=1000, kernel='linear'),
#    'parameter_search_dict': {'C': 1000, 'kernel': 'linear'}},
#   {'correlation coeff.': 0.6538307249125975,
#    'estimator_type': 'DecisionTreeRegressor',
#    'mse_test': 0.3494736842105263,
#    'mse_cross_val': 0.8316527487476982,
#    'estimator': DecisionTreeRegressor(max_depth=8, splitter='random'),
#    'parameter_search_dict': {'max_depth': 8, 'splitter': 'random'}},
#   {'correlation coeff.': 0.5119470542410067,
#    'estimator_type': 'RandomForestRegressor',
#    'mse_test': 0.3357937751063742,
#    'mse_cross_val': 0.5314082325815455,
#    'estimator': RandomForestRegressor(max_depth=5, max_features=2, n_estimators=10),
#    'parameter_search_dict': {'max_depth': 5,
#     'max_features': 2,
#     'n_estimators': 10}}],
#  'Instrument-Tissue Manipulation': [{'correlation coeff.': 0.45765015597521863,
#    'estimator_type': 'KNeighborsRegressor',
#    'mse_test': 0.46783625730994155,
#    'mse_cross_val': 0.6112169312169312,
#    'estimator': KNeighborsRegressor(n_neighbors=3),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 3}},
#   {'correlation coeff.': 0.37503747421589007,
#    'estimator_type': 'SVR',
#    'mse_test': 0.7456243019353949,
#    'mse_cross_val': 1.6746883936235686,
#    'estimator': SVR(C=1000, gamma=0.01),
#    'parameter_search_dict': {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}},
#   {'correlation coeff.': 0.31508751065487284,
#    'estimator_type': 'SVR',
#    'mse_test': 0.46507181291365174,
#    'mse_cross_val': 0.626985889864639,
#    'estimator': SVR(C=10, kernel='linear'),
#    'parameter_search_dict': {'C': 10, 'kernel': 'linear'}},
#   {'correlation coeff.': 0.32470359477934463,
#    'estimator_type': 'DecisionTreeRegressor',
#    'mse_test': 0.5730994152046783,
#    'mse_cross_val': 1.1032973544973543,
#    'estimator': DecisionTreeRegressor(max_depth=8),
#    'parameter_search_dict': {'max_depth': 8, 'splitter': 'best'}},
#   {'correlation coeff.': 0.5570472062933814,
#    'estimator_type': 'RandomForestRegressor',
#    'mse_test': 0.3701376208378087,
#    'mse_cross_val': 0.6372136243386244,
#    'estimator': RandomForestRegressor(max_depth=8, max_features=5, n_estimators=10),
#    'parameter_search_dict': {'max_depth': 8,
#     'max_features': 5,
#     'n_estimators': 10}}],
#  'Dexterity': [{'correlation coeff.': 0.6881934152166811,
#    'estimator_type': 'KNeighborsRegressor',
#    'mse_test': 0.2573099415204679,
#    'mse_cross_val': 0.528994708994709,
#    'estimator': KNeighborsRegressor(n_neighbors=3),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 3}},
#   {'correlation coeff.': 0.32280734065160455,
#    'estimator_type': 'SVR',
#    'mse_test': 0.8786209323673623,
#    'mse_cross_val': 1.1783067572684751,
#    'estimator': SVR(C=1000, gamma=0.1),
#    'parameter_search_dict': {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}},
#   {'correlation coeff.': 0.27993686301217824,
#    'estimator_type': 'SVR',
#    'mse_test': 0.45039433726252587,
#    'mse_cross_val': 0.419023977531754,
#    'estimator': SVR(C=1000, kernel='linear'),
#    'parameter_search_dict': {'C': 1000, 'kernel': 'linear'}},
#   {'correlation coeff.': 0.15707842252086018,
#    'estimator_type': 'DecisionTreeRegressor',
#    'mse_test': 0.5951763036783281,
#    'mse_cross_val': 0.7580595065615268,
#    'estimator': DecisionTreeRegressor(max_depth=5, splitter='random'),
#    'parameter_search_dict': {'max_depth': 5, 'splitter': 'random'}},
#   {'correlation coeff.': 0.5656572412793003,
#    'estimator_type': 'RandomForestRegressor',
#    'mse_test': 0.3345964535904282,
#    'mse_cross_val': 0.38654465692170087,
#    'estimator': RandomForestRegressor(max_depth=6, max_features=1, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 6,
#     'max_features': 1,
#     'n_estimators': 20}}],
#  'Flow of procedure': [{'correlation coeff.': 0.48515970484957466,
#    'estimator_type': 'KNeighborsRegressor',
#    'mse_test': 0.17434210526315788,
#    'mse_cross_val': 0.355,
#    'estimator': KNeighborsRegressor(n_neighbors=4),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 4}},
#   {'correlation coeff.': 0.2749624657077571,
#    'estimator_type': 'SVR',
#    'mse_test': 0.528964285274092,
#    'mse_cross_val': 0.7485856874056174,
#    'estimator': SVR(C=100, gamma=0.1),
#    'parameter_search_dict': {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}},
#   {'correlation coeff.': 0.208250676923119,
#    'estimator_type': 'SVR',
#    'mse_test': 0.21970522482941335,
#    'mse_cross_val': 0.3305264450873745,
#    'estimator': SVR(C=1000, kernel='linear'),
#    'parameter_search_dict': {'C': 1000, 'kernel': 'linear'}},
#   {'correlation coeff.': -0.09488401440957377,
#    'estimator_type': 'DecisionTreeRegressor',
#    'mse_test': 0.2631578947368421,
#    'mse_cross_val': 0.6739480122114205,
#    'estimator': DecisionTreeRegressor(max_depth=5, splitter='random'),
#    'parameter_search_dict': {'max_depth': 5, 'splitter': 'random'}},
#   {'correlation coeff.': 0.3896447605791739,
#    'estimator_type': 'RandomForestRegressor',
#    'mse_test': 0.17526315789473687,
#    'mse_cross_val': 0.39287600463509553,
#    'estimator': RandomForestRegressor(max_depth=6, max_features=5, n_estimators=10),
#    'parameter_search_dict': {'max_depth': 6,
#     'max_features': 5,
#     'n_estimators': 10}}],
#  'Overall': [{'correlation coeff.': 0.8006164762602483,
#    'estimator_type': 'KNeighborsRegressor',
#    'mse_test': 2.3976608187134496,
#    'mse_cross_val': 12.003280423280422,
#    'estimator': KNeighborsRegressor(n_neighbors=3),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 3}},
#   {'correlation coeff.': 0.6637862222225017,
#    'estimator_type': 'SVR',
#    'mse_test': 16.287819307682515,
#    'mse_cross_val': 23.012742611441332,
#    'estimator': SVR(C=1000, gamma=0.1),
#    'parameter_search_dict': {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}},
#   {'correlation coeff.': 0.49054120909960386,
#    'estimator_type': 'SVR',
#    'mse_test': 5.230163684734199,
#    'mse_cross_val': 10.965748775904018,
#    'estimator': SVR(C=0.025, kernel='linear'),
#    'parameter_search_dict': {'C': 0.025, 'kernel': 'linear'}},
#   {'correlation coeff.': 0.9095829028310772,
#    'estimator_type': 'DecisionTreeRegressor',
#    'mse_test': 1.1457086167800454,
#    'mse_cross_val': 18.179219142220198,
#    'estimator': DecisionTreeRegressor(max_depth=7, splitter='random'),
#    'parameter_search_dict': {'max_depth': 7, 'splitter': 'random'}},
#   {'correlation coeff.': 0.1653328094176516,
#    'estimator_type': 'RandomForestRegressor',
#    'mse_test': 7.087711738853299,
#    'mse_cross_val': 10.644009998386442,
#    'estimator': RandomForestRegressor(max_depth=7, max_features=1, n_estimators=10),
#    'parameter_search_dict': {'max_depth': 7,
#     'max_features': 1,
#     'n_estimators': 10}}]}

# %%
result = {}
for key, val in res.items():
    df = pd.DataFrame(val)
    df["Metric"] = key
    result[key]= df

# %%
data_reg = pd.concat(result)

# %%
data_reg
# Out:
#                                   correlation coeff.  \
# Dexterity                      0            0.688193
#                                1            0.322807
#                                2            0.279937
#                                3            0.157078
#                                4            0.565657
# Flow of procedure              0            0.485160
#                                1            0.274962
#                                2            0.208251
#                                3           -0.094884
#                                4            0.389645
# Hand-eye Coordination          0            0.533066
#                                1            0.331686
#                                2            0.559564
#                                3            0.653831
#                                4            0.511947
# Instrument-Tissue Manipulation 0            0.457650
#                                1            0.375037
#                                2            0.315088
#                                3            0.324704
#                                4            0.557047
# Overall                        0            0.800616
#                                1            0.663786
#                                2            0.490541
#                                3            0.909583
#                                4            0.165333
#
#                                                                           estimator  \
# Dexterity                      0                 KNeighborsRegressor(n_neighbors=3)
#                                1                             SVR(C=1000, gamma=0.1)
#                                2                       SVR(C=1000, kernel='linear')
#                                3  DecisionTreeRegressor(max_depth=5, splitter='r...
#                                4  (DecisionTreeRegressor(max_depth=6, max_featur...
# Flow of procedure              0                 KNeighborsRegressor(n_neighbors=4)
#                                1                              SVR(C=100, gamma=0.1)
#                                2                       SVR(C=1000, kernel='linear')
#                                3  DecisionTreeRegressor(max_depth=5, splitter='r...
#                                4  (DecisionTreeRegressor(max_depth=6, max_featur...
# Hand-eye Coordination          0                 KNeighborsRegressor(n_neighbors=3)
#                                1                            SVR(C=1000, gamma=0.01)
#                                2                       SVR(C=1000, kernel='linear')
#                                3  DecisionTreeRegressor(max_depth=8, splitter='r...
#                                4  (DecisionTreeRegressor(max_depth=5, max_featur...
# Instrument-Tissue Manipulation 0                 KNeighborsRegressor(n_neighbors=3)
#                                1                            SVR(C=1000, gamma=0.01)
#                                2                         SVR(C=10, kernel='linear')
#                                3                 DecisionTreeRegressor(max_depth=8)
#                                4  (DecisionTreeRegressor(max_depth=8, max_featur...
# Overall                        0                 KNeighborsRegressor(n_neighbors=3)
#                                1                             SVR(C=1000, gamma=0.1)
#                                2                      SVR(C=0.025, kernel='linear')
#                                3  DecisionTreeRegressor(max_depth=7, splitter='r...
#                                4  (DecisionTreeRegressor(max_depth=7, max_featur...
#
#                                          estimator_type  mse_cross_val  \
# Dexterity                      0    KNeighborsRegressor       0.528995
#                                1                    SVR       1.178307
#                                2                    SVR       0.419024
#                                3  DecisionTreeRegressor       0.758060
#                                4  RandomForestRegressor       0.386545
# Flow of procedure              0    KNeighborsRegressor       0.355000
#                                1                    SVR       0.748586
#                                2                    SVR       0.330526
#                                3  DecisionTreeRegressor       0.673948
#                                4  RandomForestRegressor       0.392876
# Hand-eye Coordination          0    KNeighborsRegressor       0.487725
#                                1                    SVR       1.081936
#                                2                    SVR       0.435329
#                                3  DecisionTreeRegressor       0.831653
#                                4  RandomForestRegressor       0.531408
# Instrument-Tissue Manipulation 0    KNeighborsRegressor       0.611217
#                                1                    SVR       1.674688
#                                2                    SVR       0.626986
#                                3  DecisionTreeRegressor       1.103297
#                                4  RandomForestRegressor       0.637214
# Overall                        0    KNeighborsRegressor      12.003280
#                                1                    SVR      23.012743
#                                2                    SVR      10.965749
#                                3  DecisionTreeRegressor      18.179219
#                                4  RandomForestRegressor      10.644010
#
#                                    mse_test  \
# Dexterity                      0   0.257310
#                                1   0.878621
#                                2   0.450394
#                                3   0.595176
#                                4   0.334596
# Flow of procedure              0   0.174342
#                                1   0.528964
#                                2   0.219705
#                                3   0.263158
#                                4   0.175263
# Hand-eye Coordination          0   0.345029
#                                1   0.620732
#                                2   0.324693
#                                3   0.349474
#                                4   0.335794
# Instrument-Tissue Manipulation 0   0.467836
#                                1   0.745624
#                                2   0.465072
#                                3   0.573099
#                                4   0.370138
# Overall                        0   2.397661
#                                1  16.287819
#                                2   5.230164
#                                3   1.145709
#                                4   7.087712
#
#                                                               parameter_search_dict  \
# Dexterity                      0            {'algorithm': 'auto', 'n_neighbors': 3}
#                                1         {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
#                                2                    {'C': 1000, 'kernel': 'linear'}
#                                3             {'max_depth': 5, 'splitter': 'random'}
#                                4  {'max_depth': 6, 'max_features': 1, 'n_estimat...
# Flow of procedure              0            {'algorithm': 'auto', 'n_neighbors': 4}
#                                1          {'C': 100, 'gamma': 0.1, 'kernel': 'rbf'}
#                                2                    {'C': 1000, 'kernel': 'linear'}
#                                3             {'max_depth': 5, 'splitter': 'random'}
#                                4  {'max_depth': 6, 'max_features': 5, 'n_estimat...
# Hand-eye Coordination          0            {'algorithm': 'auto', 'n_neighbors': 3}
#                                1        {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
#                                2                    {'C': 1000, 'kernel': 'linear'}
#                                3             {'max_depth': 8, 'splitter': 'random'}
#                                4  {'max_depth': 5, 'max_features': 2, 'n_estimat...
# Instrument-Tissue Manipulation 0            {'algorithm': 'auto', 'n_neighbors': 3}
#                                1        {'C': 1000, 'gamma': 0.01, 'kernel': 'rbf'}
#                                2                      {'C': 10, 'kernel': 'linear'}
#                                3               {'max_depth': 8, 'splitter': 'best'}
#                                4  {'max_depth': 8, 'max_features': 5, 'n_estimat...
# Overall                        0            {'algorithm': 'auto', 'n_neighbors': 3}
#                                1         {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
#                                2                   {'C': 0.025, 'kernel': 'linear'}
#                                3             {'max_depth': 7, 'splitter': 'random'}
#                                4  {'max_depth': 7, 'max_features': 1, 'n_estimat...
#
#                                                           Metric
# Dexterity                      0                       Dexterity
#                                1                       Dexterity
#                                2                       Dexterity
#                                3                       Dexterity
#                                4                       Dexterity
# Flow of procedure              0               Flow of procedure
#                                1               Flow of procedure
#                                2               Flow of procedure
#                                3               Flow of procedure
#                                4               Flow of procedure
# Hand-eye Coordination          0           Hand-eye Coordination
#                                1           Hand-eye Coordination
#                                2           Hand-eye Coordination
#                                3           Hand-eye Coordination
#                                4           Hand-eye Coordination
# Instrument-Tissue Manipulation 0  Instrument-Tissue Manipulation
#                                1  Instrument-Tissue Manipulation
#                                2  Instrument-Tissue Manipulation
#                                3  Instrument-Tissue Manipulation
#                                4  Instrument-Tissue Manipulation
# Overall                        0                         Overall
#                                1                         Overall
#                                2                         Overall
#                                3                         Overall
#                                4                         Overall

# %%
data_reg.to_csv("./data_reg_without_Upsampling_1.csv")

# %%
res_up = {}
for p in preds:
    res_up[p]=trainer.run(regressors,params_regressors, names,p,method="regression", upsample = True, split_size= 0.3)
# Out:
# Hand-eye Coordination KNeighborsRegressor()
# Hand-eye Coordination SVR()
# Hand-eye Coordination SVR()
# Hand-eye Coordination DecisionTreeRegressor()
# Hand-eye Coordination RandomForestRegressor()
# Instrument-Tissue Manipulation KNeighborsRegressor()
# Instrument-Tissue Manipulation SVR()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/scipy/stats/stats.py:3010: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# Instrument-Tissue Manipulation SVR()
# Instrument-Tissue Manipulation DecisionTreeRegressor()
# Instrument-Tissue Manipulation RandomForestRegressor()
# Dexterity KNeighborsRegressor()
# Dexterity SVR()
# Dexterity SVR()
# Dexterity DecisionTreeRegressor()
# Dexterity RandomForestRegressor()
# Flow of procedure KNeighborsRegressor()
# Flow of procedure SVR()
# /home/kunaldargan/ROBO_SURGERY/env/lib/python3.6/site-packages/scipy/stats/stats.py:3010: RuntimeWarning: invalid value encountered in double_scalars
#   r = r_num / r_den
# Flow of procedure SVR()
# Flow of procedure DecisionTreeRegressor()
# Flow of procedure RandomForestRegressor()
# Overall KNeighborsRegressor()
# Overall SVR()
# Overall SVR()
# Overall DecisionTreeRegressor()
# Overall RandomForestRegressor()

# %%
res_up
# Out:
# {'Hand-eye Coordination': [{'correlation coeff.': 0.6086594872094194,
#    'estimator_type': 'KNeighborsRegressor',
#    'mse_test': 0.26000000000000006,
#    'mse_cross_val': 0.33604,
#    'estimator': KNeighborsRegressor(),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 5}},
#   {'correlation coeff.': 0.3951185853419004,
#    'estimator_type': 'SVR',
#    'mse_test': 1.0333293608891982,
#    'mse_cross_val': 1.7898120185498445,
#    'estimator': SVR(C=1, gamma=0.0001),
#    'parameter_search_dict': {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}},
#   {'correlation coeff.': 0.517427402588045,
#    'estimator_type': 'SVR',
#    'mse_test': 0.32266675873758416,
#    'mse_cross_val': 0.3917091922882582,
#    'estimator': SVR(C=0.025, kernel='linear'),
#    'parameter_search_dict': {'C': 0.025, 'kernel': 'linear'}},
#   {'correlation coeff.': 0.3239950492136736,
#    'estimator_type': 'DecisionTreeRegressor',
#    'mse_test': 0.435913508260447,
#    'mse_cross_val': 0.515343192578426,
#    'estimator': DecisionTreeRegressor(max_depth=4, splitter='random'),
#    'parameter_search_dict': {'max_depth': 4, 'splitter': 'random'}},
#   {'correlation coeff.': 0.49487658185853567,
#    'estimator_type': 'RandomForestRegressor',
#    'mse_test': 0.31851160375075016,
#    'mse_cross_val': 0.3504465886361333,
#    'estimator': RandomForestRegressor(max_depth=4, max_features=1, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 4,
#     'max_features': 1,
#     'n_estimators': 20}}],
#  'Instrument-Tissue Manipulation': [{'correlation coeff.': 0.38879855183726275,
#    'estimator_type': 'KNeighborsRegressor',
#    'mse_test': 0.6171428571428572,
#    'mse_cross_val': 0.4268571428571429,
#    'estimator': KNeighborsRegressor(),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 5}},
#   {'correlation coeff.': 0.22988192496447463,
#    'estimator_type': 'SVR',
#    'mse_test': 0.7252935046307741,
#    'mse_cross_val': 1.8731885798390546,
#    'estimator': SVR(C=1, gamma=0.0001),
#    'parameter_search_dict': {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}},
#   {'correlation coeff.': 0.3422800519188792,
#    'estimator_type': 'SVR',
#    'mse_test': 0.5235574047264611,
#    'mse_cross_val': 0.8280489656419359,
#    'estimator': SVR(C=0.025, kernel='linear'),
#    'parameter_search_dict': {'C': 0.025, 'kernel': 'linear'}},
#   {'correlation coeff.': 0.2021688714323641,
#    'estimator_type': 'DecisionTreeRegressor',
#    'mse_test': 0.9452195917224272,
#    'mse_cross_val': 0.5397877683995408,
#    'estimator': DecisionTreeRegressor(max_depth=4, splitter='random'),
#    'parameter_search_dict': {'max_depth': 4, 'splitter': 'random'}},
#   {'correlation coeff.': 0.24713754430717627,
#    'estimator_type': 'RandomForestRegressor',
#    'mse_test': 0.5428340325755142,
#    'mse_cross_val': 0.37202624031642983,
#    'estimator': RandomForestRegressor(max_depth=4, max_features=2, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 4,
#     'max_features': 2,
#     'n_estimators': 20}}],
#  'Dexterity': [{'correlation coeff.': 0.6927699415910573,
#    'estimator_type': 'KNeighborsRegressor',
#    'mse_test': 0.20714285714285713,
#    'mse_cross_val': 0.4778522167487685,
#    'estimator': KNeighborsRegressor(),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 5}},
#   {'correlation coeff.': 0.4646280659817128,
#    'estimator_type': 'SVR',
#    'mse_test': 1.2545857049090248,
#    'mse_cross_val': 1.9204514605186944,
#    'estimator': SVR(C=1, gamma=0.0001),
#    'parameter_search_dict': {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}},
#   {'correlation coeff.': 0.38495890304391045,
#    'estimator_type': 'SVR',
#    'mse_test': 0.5112654882470813,
#    'mse_cross_val': 0.9561247407498229,
#    'estimator': SVR(C=0.025, kernel='linear'),
#    'parameter_search_dict': {'C': 0.025, 'kernel': 'linear'}},
#   {'correlation coeff.': 0.363199847308847,
#    'estimator_type': 'DecisionTreeRegressor',
#    'mse_test': 0.41384202012176363,
#    'mse_cross_val': 0.6990587661057689,
#    'estimator': DecisionTreeRegressor(max_depth=4, splitter='random'),
#    'parameter_search_dict': {'max_depth': 4, 'splitter': 'random'}},
#   {'correlation coeff.': 0.3519545787381958,
#    'estimator_type': 'RandomForestRegressor',
#    'mse_test': 0.38443083243409226,
#    'mse_cross_val': 0.3765185571791065,
#    'estimator': RandomForestRegressor(max_depth=4, max_features=5, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 4,
#     'max_features': 5,
#     'n_estimators': 20}}],
#  'Flow of procedure': [{'correlation coeff.': 0.20680032256148612,
#    'estimator_type': 'KNeighborsRegressor',
#    'mse_test': 0.2742857142857143,
#    'mse_cross_val': 0.39100000000000007,
#    'estimator': KNeighborsRegressor(),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 5}},
#   {'correlation coeff.': 0.09196787892232668,
#    'estimator_type': 'SVR',
#    'mse_test': 1.6007183537704504,
#    'mse_cross_val': 1.777007290810042,
#    'estimator': SVR(C=1, gamma=0.0001),
#    'parameter_search_dict': {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}},
#   {'correlation coeff.': -0.07430624024884998,
#    'estimator_type': 'SVR',
#    'mse_test': 0.7517173144271369,
#    'mse_cross_val': 0.6904972475466996,
#    'estimator': SVR(C=1000, kernel='linear'),
#    'parameter_search_dict': {'C': 1000, 'kernel': 'linear'}},
#   {'correlation coeff.': -0.17780701431861318,
#    'estimator_type': 'DecisionTreeRegressor',
#    'mse_test': 0.32277380202238426,
#    'mse_cross_val': 0.5064348873081823,
#    'estimator': DecisionTreeRegressor(max_depth=4),
#    'parameter_search_dict': {'max_depth': 4, 'splitter': 'best'}},
#   {'correlation coeff.': 0.014799284995053312,
#    'estimator_type': 'RandomForestRegressor',
#    'mse_test': 0.281131827491389,
#    'mse_cross_val': 0.3760498213088372,
#    'estimator': RandomForestRegressor(max_depth=4, max_features=1, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 4,
#     'max_features': 1,
#     'n_estimators': 20}}],
#  'Overall': [{'correlation coeff.': 0.39567820159528266,
#    'estimator_type': 'KNeighborsRegressor',
#    'mse_test': 7.61,
#    'mse_cross_val': 16.97510873440285,
#    'estimator': KNeighborsRegressor(),
#    'parameter_search_dict': {'algorithm': 'auto', 'n_neighbors': 5}},
#   {'correlation coeff.': 0.5686240349246453,
#    'estimator_type': 'SVR',
#    'mse_test': 27.73472038783363,
#    'mse_cross_val': 66.39889157677092,
#    'estimator': SVR(C=1000, gamma=0.1),
#    'parameter_search_dict': {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}},
#   {'correlation coeff.': 0.33483874713630074,
#    'estimator_type': 'SVR',
#    'mse_test': 11.550565597230639,
#    'mse_cross_val': 15.696837781897894,
#    'estimator': SVR(C=1000, kernel='linear'),
#    'parameter_search_dict': {'C': 1000, 'kernel': 'linear'}},
#   {'correlation coeff.': 0.207520796822878,
#    'estimator_type': 'DecisionTreeRegressor',
#    'mse_test': 10.362493249191289,
#    'mse_cross_val': 38.951588601183246,
#    'estimator': DecisionTreeRegressor(max_depth=6, splitter='random'),
#    'parameter_search_dict': {'max_depth': 6, 'splitter': 'random'}},
#   {'correlation coeff.': 0.4940233603324753,
#    'estimator_type': 'RandomForestRegressor',
#    'mse_test': 5.4033861081656624,
#    'mse_cross_val': 24.92523866947581,
#    'estimator': RandomForestRegressor(max_depth=8, max_features=5, n_estimators=20),
#    'parameter_search_dict': {'max_depth': 8,
#     'max_features': 5,
#     'n_estimators': 20}}]}

# %%
result_reg_up = {}
for key, val in res_up.items():
    df = pd.DataFrame(val)
    df["Metric"] = key
    result_reg_up[key]= df

# %%
data_reg_up = pd.concat(result_reg_up)

# %%
data_reg_up
# Out:
#                                   correlation coeff.  \
# Dexterity                      0            0.692770
#                                1            0.464628
#                                2            0.384959
#                                3            0.363200
#                                4            0.351955
# Flow of procedure              0            0.206800
#                                1            0.091968
#                                2           -0.074306
#                                3           -0.177807
#                                4            0.014799
# Hand-eye Coordination          0            0.608659
#                                1            0.395119
#                                2            0.517427
#                                3            0.323995
#                                4            0.494877
# Instrument-Tissue Manipulation 0            0.388799
#                                1            0.229882
#                                2            0.342280
#                                3            0.202169
#                                4            0.247138
# Overall                        0            0.395678
#                                1            0.568624
#                                2            0.334839
#                                3            0.207521
#                                4            0.494023
#
#                                                                           estimator  \
# Dexterity                      0                              KNeighborsRegressor()
#                                1                             SVR(C=1, gamma=0.0001)
#                                2                      SVR(C=0.025, kernel='linear')
#                                3  DecisionTreeRegressor(max_depth=4, splitter='r...
#                                4  (DecisionTreeRegressor(max_depth=4, max_featur...
# Flow of procedure              0                              KNeighborsRegressor()
#                                1                             SVR(C=1, gamma=0.0001)
#                                2                       SVR(C=1000, kernel='linear')
#                                3                 DecisionTreeRegressor(max_depth=4)
#                                4  (DecisionTreeRegressor(max_depth=4, max_featur...
# Hand-eye Coordination          0                              KNeighborsRegressor()
#                                1                             SVR(C=1, gamma=0.0001)
#                                2                      SVR(C=0.025, kernel='linear')
#                                3  DecisionTreeRegressor(max_depth=4, splitter='r...
#                                4  (DecisionTreeRegressor(max_depth=4, max_featur...
# Instrument-Tissue Manipulation 0                              KNeighborsRegressor()
#                                1                             SVR(C=1, gamma=0.0001)
#                                2                      SVR(C=0.025, kernel='linear')
#                                3  DecisionTreeRegressor(max_depth=4, splitter='r...
#                                4  (DecisionTreeRegressor(max_depth=4, max_featur...
# Overall                        0                              KNeighborsRegressor()
#                                1                             SVR(C=1000, gamma=0.1)
#                                2                       SVR(C=1000, kernel='linear')
#                                3  DecisionTreeRegressor(max_depth=6, splitter='r...
#                                4  (DecisionTreeRegressor(max_depth=8, max_featur...
#
#                                          estimator_type  mse_cross_val  \
# Dexterity                      0    KNeighborsRegressor       0.477852
#                                1                    SVR       1.920451
#                                2                    SVR       0.956125
#                                3  DecisionTreeRegressor       0.699059
#                                4  RandomForestRegressor       0.376519
# Flow of procedure              0    KNeighborsRegressor       0.391000
#                                1                    SVR       1.777007
#                                2                    SVR       0.690497
#                                3  DecisionTreeRegressor       0.506435
#                                4  RandomForestRegressor       0.376050
# Hand-eye Coordination          0    KNeighborsRegressor       0.336040
#                                1                    SVR       1.789812
#                                2                    SVR       0.391709
#                                3  DecisionTreeRegressor       0.515343
#                                4  RandomForestRegressor       0.350447
# Instrument-Tissue Manipulation 0    KNeighborsRegressor       0.426857
#                                1                    SVR       1.873189
#                                2                    SVR       0.828049
#                                3  DecisionTreeRegressor       0.539788
#                                4  RandomForestRegressor       0.372026
# Overall                        0    KNeighborsRegressor      16.975109
#                                1                    SVR      66.398892
#                                2                    SVR      15.696838
#                                3  DecisionTreeRegressor      38.951589
#                                4  RandomForestRegressor      24.925239
#
#                                    mse_test  \
# Dexterity                      0   0.207143
#                                1   1.254586
#                                2   0.511265
#                                3   0.413842
#                                4   0.384431
# Flow of procedure              0   0.274286
#                                1   1.600718
#                                2   0.751717
#                                3   0.322774
#                                4   0.281132
# Hand-eye Coordination          0   0.260000
#                                1   1.033329
#                                2   0.322667
#                                3   0.435914
#                                4   0.318512
# Instrument-Tissue Manipulation 0   0.617143
#                                1   0.725294
#                                2   0.523557
#                                3   0.945220
#                                4   0.542834
# Overall                        0   7.610000
#                                1  27.734720
#                                2  11.550566
#                                3  10.362493
#                                4   5.403386
#
#                                                               parameter_search_dict  \
# Dexterity                      0            {'algorithm': 'auto', 'n_neighbors': 5}
#                                1         {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
#                                2                   {'C': 0.025, 'kernel': 'linear'}
#                                3             {'max_depth': 4, 'splitter': 'random'}
#                                4  {'max_depth': 4, 'max_features': 5, 'n_estimat...
# Flow of procedure              0            {'algorithm': 'auto', 'n_neighbors': 5}
#                                1         {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
#                                2                    {'C': 1000, 'kernel': 'linear'}
#                                3               {'max_depth': 4, 'splitter': 'best'}
#                                4  {'max_depth': 4, 'max_features': 1, 'n_estimat...
# Hand-eye Coordination          0            {'algorithm': 'auto', 'n_neighbors': 5}
#                                1         {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
#                                2                   {'C': 0.025, 'kernel': 'linear'}
#                                3             {'max_depth': 4, 'splitter': 'random'}
#                                4  {'max_depth': 4, 'max_features': 1, 'n_estimat...
# Instrument-Tissue Manipulation 0            {'algorithm': 'auto', 'n_neighbors': 5}
#                                1         {'C': 1, 'gamma': 0.0001, 'kernel': 'rbf'}
#                                2                   {'C': 0.025, 'kernel': 'linear'}
#                                3             {'max_depth': 4, 'splitter': 'random'}
#                                4  {'max_depth': 4, 'max_features': 2, 'n_estimat...
# Overall                        0            {'algorithm': 'auto', 'n_neighbors': 5}
#                                1         {'C': 1000, 'gamma': 0.1, 'kernel': 'rbf'}
#                                2                    {'C': 1000, 'kernel': 'linear'}
#                                3             {'max_depth': 6, 'splitter': 'random'}
#                                4  {'max_depth': 8, 'max_features': 5, 'n_estimat...
#
#                                                           Metric
# Dexterity                      0                       Dexterity
#                                1                       Dexterity
#                                2                       Dexterity
#                                3                       Dexterity
#                                4                       Dexterity
# Flow of procedure              0               Flow of procedure
#                                1               Flow of procedure
#                                2               Flow of procedure
#                                3               Flow of procedure
#                                4               Flow of procedure
# Hand-eye Coordination          0           Hand-eye Coordination
#                                1           Hand-eye Coordination
#                                2           Hand-eye Coordination
#                                3           Hand-eye Coordination
#                                4           Hand-eye Coordination
# Instrument-Tissue Manipulation 0  Instrument-Tissue Manipulation
#                                1  Instrument-Tissue Manipulation
#                                2  Instrument-Tissue Manipulation
#                                3  Instrument-Tissue Manipulation
#                                4  Instrument-Tissue Manipulation
# Overall                        0                         Overall
#                                1                         Overall
#                                2                         Overall
#                                3                         Overall
#                                4                         Overall

# %%
data_reg_up.to_csv("./data_reg_with_Upsampling_1.csv")

# %%
#################End of Main #####################################
